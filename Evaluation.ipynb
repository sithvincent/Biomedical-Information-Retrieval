# %%
import helper.pubmed_search as pubs
from helper.pubmed_search import QueryExpansionManager
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import random
import time
import json
import math
import csv
import os


def precision_at_k(retrieved_docs, relevant_docs, k=10):
    # k = min(k, len(retrieved_docs))  # Handle case where retrieved_docs < k
    k = len(relevant_docs)  # Handle case where retrieved_docs < k
    relevant_in_top_k = [doc for doc in retrieved_docs[:k] if doc in relevant_docs]
    return 100*len(relevant_in_top_k) / k if k > 0 else 0.0


def average_precision_at_k(retrieved_docs, relevant_docs, k=10):
    # k = min(k, len(retrieved_docs))  # Handle case where retrieved_docs < k
    k = len(relevant_docs) # Handle case where retrieved_docs < k
    if k == 0:
        return 0.0
    num_relevant = 0
    precision_sum = 0    
    if len(retrieved_docs) != 0:
        for i in range(1, k + 1):
            if retrieved_docs[i - 1] in relevant_docs:
                num_relevant += 1
                precision_sum += num_relevant / i
    
    # Use the smaller of k or total number of relevant documents
    # return 100*precision_sum / min(len(relevant_docs), k) if num_relevant > 0 else 0.0
    return 100*precision_sum / k if num_relevant > 0 else 0.0


def dcg(retrieved_docs, relevant_docs, k):
    dcg_value = 0.0
    if len(retrieved_docs)!=0:
        for i in range(k):
            if retrieved_docs[i] in relevant_docs:
                dcg_value += 1 / math.log2(i + 2)  # i + 2 because of 0-based indexing
    return dcg_value
def idcg(relevant_docs, k):
    idcg_value = 0.0
    # for i in range(min(len(relevant_docs), k)):
    for i in range(k):
        idcg_value += 1 / math.log2(i + 2)
    return idcg_value
def ndcg_at_k(retrieved_docs, relevant_docs, k=10):
    # k = min(k, len(retrieved_docs))  # Handle case where retrieved_docs < k
    k = len(relevant_docs)  # Handle case where retrieved_docs < k
    if k == 0:
        return 0.0

    # def dcg(retrieved_docs, relevant_docs, k):
    #     dcg_value = 0.0
    #     for i in range(k):
    #         if retrieved_docs[i] in relevant_docs:
    #             dcg_value += 1 / math.log2(i + 2)  # i + 2 because of 0-based indexing
    #     return dcg_value

    # def idcg(relevant_docs, k):
    #     idcg_value = 0.0
    #     for i in range(min(len(relevant_docs), k)):
    #         idcg_value += 1 / math.log2(i + 2)
    #     return idcg_value
    
    dcg_value = dcg(retrieved_docs, relevant_docs, k)
    idcg_value = idcg(relevant_docs, k)
    
    return 100*dcg_value / idcg_value if idcg_value > 0 else 0.0


def extract_subset_of_evaluation_data(evaluation_data, filename, fraction = 0.5, random_seed = 31):   
    random.seed(random_seed) 
    subset = random.sample(evaluation_data, int(len(evaluation_data)*fraction))
    with open (filename, 'w') as outfile:
        json.dump(subset, outfile)
    print('Extracted', len(subset), 'documents out of', len(evaluation_data))

def output_full_metrics_to_file(retrieved_ids_list, ground_truth_list, name, file_name):
    # precision at k values
    metric_list = []
    for i in range (len(retrieved_ids_list)):
        metric_list.append(precision_at_k(retrieved_ids_list[i], ground_truth_list[i]))
    mean_precision_at_k = sum(metric_list)/len(metric_list) 

    # average precision at k values
    metric_list = []
    for i in range (len(retrieved_ids_list)):
        metric_list.append(average_precision_at_k(retrieved_ids_list[i], ground_truth_list[i]))
    mean_average_precision_at_k = sum(metric_list)/len(metric_list)

    # ndcg at k values
    metric_list = []
    for i in range (len(retrieved_ids_list)):
        metric_list.append(ndcg_at_k(retrieved_ids_list[i], ground_truth_list[i]))
    mean_ndcg_at_k = sum(metric_list)/len(metric_list)

    output_list = [name, mean_precision_at_k, mean_average_precision_at_k, mean_ndcg_at_k]    

    # Check if file exists
    file_exists = os.path.isfile(file_name)
    # Open the file in append mode ('a') and create it if it doesn't exist
    with open(file_name, mode='a', newline='') as file:
        writer = csv.writer(file)
        # Write the header if the file is new
        if not file_exists:
            # Customize the header if needed, here assuming just column numbers
            header = [f"Column {i+1}" for i in range(len(output_list))]
            writer.writerow(header)
        # Write the data list
        writer.writerow(output_list)
    print(f"List successfully written to {file_name}")


def length_check(retrieved_ids_list, ground_truth_list):
    if len(retrieved_ids_list)!=len(ground_truth_list):
        print('Different length!')
    inconsistent_indexes = 0
    for i in range (len(retrieved_ids_list)):
        retrieved_ids_length = len(retrieved_ids_list[i])
        ground_truth_length = len(ground_truth_list[i])
        if retrieved_ids_length!=ground_truth_length:
            print('Inconsistency at index:', i, 'where retrieved ids have length:', retrieved_ids_length, 'and ground truth has length', ground_truth_length)
            inconsistent_indexes +=1
    return inconsistent_indexes

# %% [markdown]
# Extracts out a subset (25%) of the full test-set data and store it in a JSON for brevity. Already done so things are commented out.

# %%
# with open ('evaluation/BioASQ-training11b/training11b.json') as training_file:
#     full_evaluation_data = json.load(training_file)
# extract_subset_of_evaluation_data(full_evaluation_data['questions'], 'evaluation/testing_script.json', 0.002)

# %% [markdown]
# # 2. Evaluation For Initial Retrieval
#
# This part measures the accuracy of the results returned from the initial query without any query expansion. It covers:
# 1. Testing immediate results from a pubmed search.
# 2. Testing the results ranked by an embedding model that compares article content to the
#
# Extract the subset evaluation data and run evaluation on it.

# %%
# Method to rank relevance of documents
def get_initial_retrieved_and_ground_truth_docs(evaluation_set, remove_stop_words = False, articles_to_retrieve = 20, qe_manager = None):
    retrieved_ids_list = []
    ground_truth_list = []
    # Run it through the system:
    for idx, entry in enumerate(evaluation_set):
        # # Include this for diagnostics only, otherwise comment it out
        # if idx > 0:
        #     continue
        # Extract out the query
        query = entry['body']        
        # When running the evaluation, there is a tendency for the internet to break so we need to continuously try to connnect
        runs = 0
        while True:
            if qe_manager is None:
                time.sleep(1) # rest for 1 second so as not to overwhelm PubMed's API if there is no re-ranking
            # query the question through the database and extract the relevant documents
            # try:
            print('Query number', idx, 'is: ', query)
            if qe_manager is not None:
                query_embedding = qe_manager.embed_mesh_headings_preloaded_model(query)
            query_response = pubs.get_query_response(query, remove_stop_words=remove_stop_words, articles_to_retrieve=articles_to_retrieve)
            ground_truth = [x.split('/')[-1] for x in entry['documents']] 
            ground_truth_length = len (ground_truth)   
            ground_truth_list.append(ground_truth)   
            # Checks if there is idlist in the results, then append it to the list
            # If not (usually because of pubmed search errors or the preprocessing removed all words from the query), append an empty list                
            if 'idlist' in query_response['esearchresult']:
                retrieved_ids = query_response['esearchresult']['idlist']
                if retrieved_ids == []:
                    retrieved_ids_list.append([])
                    break
                # If we decide to rank the retrieval before returning the list
                if qe_manager is not None:
                    ranking_list = []
                    retrieved_article_details = pubs.get_article_details_from_id(retrieved_ids)
                    for key, value in retrieved_article_details.items():
                        title = value.get('Title') or ""
                        abstract = value.get('Abstract') or ""
                        article_title_abstract = title + abstract
                        article_title_abstract_embeddings = qe_manager.embed_mesh_headings_preloaded_model(article_title_abstract)
                        similarity = cosine_similarity(query_embedding, article_title_abstract_embeddings)[0][0]
                        ranking_list.append({'Article': key, 'Similarity': similarity})
                    # If the ranking list is shorter than ground truth, need to pad it
                    if len(ranking_list) < ground_truth_length:
                        entries_to_add = ground_truth_length - len(ranking_list)
                        for i in range(entries_to_add):
                            ranking_list.append({'Article': 'None', 'Similarity': 0})
                    ranking_list_df = pd.DataFrame(ranking_list).sort_values(by=['Similarity'], ascending=False)
                    ranking_list_df.to_csv('evaluation/simple_retrieval_articles.csv')
                    # If the ranking list is longer than ground truth, need to trim it
                    retrieved_ids_list.append(ranking_list_df.head(ground_truth_length)['Article'].to_list())
                else:
                    if len(retrieved_ids) < ground_truth_length:
                        entries_to_add = ground_truth_length - len(retrieved_ids)
                        for i in range(entries_to_add):
                            retrieved_ids.append('')
                    else: # for the case where the lengths are equal or ground truth is shorter
                        retrieved_ids = retrieved_ids[0:ground_truth_length]
                    retrieved_ids_list.append(retrieved_ids)  
            else: 
                retrieved_ids_list.append([])                      
            break # once information is extracted, stop the rerun
            # # This is just to pre-ampt anything that would happen above during long evaluation runs.
            # except Exception as e:
            #     print('Error occured when querying pubmed:', e)
            #     runs +=1
            #     if runs > 3: # after 3 rounds of rerun due to errors, just move on
            #         print('This entry is not counted:', entry['body'])
            #         break 
    return retrieved_ids_list, ground_truth_list

# %% [markdown]
# ### 2.1 Immediate Results from PubMed Entrez Search

# %%
with open ('evaluation/small subset.json') as infile:
    evaluation = json.load(infile)

# pure retrieval on a fixed dataset (takes 31.7s compared to retrieval + p@k ranking at 33.3s)
retrieved_ids_list, ground_truth_list = get_initial_retrieved_and_ground_truth_docs(evaluation, remove_stop_words=False)
output_full_metrics_to_file(retrieved_ids_list, ground_truth_list, 'baseline (initial retrieval, 10 articles retrieved, no reranking, 233 documents) trimming', 'evaluation/evaluation_metrics.csv')
# Out:
# Query number 0 is:  What is the function of the AIRE gene at the embryonic stage?
# Query number 1 is:  Which type of analysis does DeSeq2 perform?
# Query number 2 is:  Which intraflagellar transport (IFT) motor protein has been linked to human skeletal ciliopathies?
# Query number 3 is:  Where in the body, is ghrelin secreted?
# Query number 4 is:  What is the effect of SAHA treatment in Huntington's disease?
# Query number 5 is:  What is membrane scission?
# Query number 6 is:  What is the color of the protein Ranasmurfin?
# Query number 7 is:  What is the mechanism of action of ocrelizumab for treatment of multiple sclerosis?
# Query number 8 is:  What treatment was studied in the KEYNOTE-522 trial?
# Query number 9 is:  Is Stat4 a transcription factor?
# Query number 10 is:  By which methods can we evaluate the reliability of a phylogenetic tree?
# Query number 11 is:  What is the physiological role of LKB1 involved in Peutz-Jeghers syndrome?
# Query number 12 is:  Is the Dictyostelium discoideum proteome known?
# Query number 13 is:  Which disease of the central nervous system is characterized by the presence of Lewy bodies?
# Query number 14 is:  What is the content of the METLIN database?
# Query number 15 is:  What is formin associated with in the snail?
# Query number 16 is:  Describe bigPint
# Query number 17 is:  What is the target of galcanezumab?
# Query number 18 is:  What is the mechanism of action of Vericiguat?
# Query number 19 is:  Is NicVAX vaccine effective for smoking cessation?
# Query number 20 is:  Which is the process that Conserved noncoding elements mostly regulate?
# Query number 21 is:  What is the effect of a defective CLN3 gene?
# Query number 22 is:  Are CTCF and BORIS involved in genome regulation and cancer?
# Query number 23 is:  Are there any statistical methods for normalizing and identifying differential regions in histone modification ChIP-seq data?
# Query number 24 is:  How is Slc22a3 imprinted?
# Query number 25 is:  Is selenocysteine an aminoacid?
# Query number 26 is:  Can adult humans be induced to produce fetal hemoglobin?
# Query number 27 is:  Which is the histone residue methylated by MLL1?
# Query number 28 is:  Which are the two main bacterial phyla in human gut?
# Query number 29 is:  Are cardenolides inhibitors of Na+/K+ ATPase?
# Query number 30 is:  Sweat Chloride Testing is used  for which disease?
# Query number 31 is:  Which gene is mutated in the Karak syndrome?
# Query number 32 is:  Does fibronectin constitute a serum biomarker for Duchenne muscular dystrophy?
# Query number 33 is:  Which gene-defect causes the Vel-blood type?
# Query number 34 is:  In which chromosome are transgenes inserted in the case of the LiPS-A3S line?
# Query number 35 is:  Which company developed Waylivra?
# Query number 36 is:  Which are the characteristics of  Andersen syndrome?
# Query number 37 is:  How effective is the dentritic cells treatment on cancer?
# Query number 38 is:  What is the typical rash associated with gluten ?
# Query number 39 is:  Which disease can be classified with the Awaji Criteria?
# Query number 40 is:  Is miR-21 related to carcinogenesis?
# Query number 41 is:  What is the mechanism of drug-induced gingival overgrowth?
# Query number 42 is:  What is known about depression in caregivers of brain tumor patients?
# Query number 43 is:  Describe CapSim
# Query number 44 is:  Is low T3 syndrome a prognostic marker in patients with renal insufficiency?
# Query number 45 is:  Is Bladder training an effective method to treat  urge incontinence ?
# Query number 46 is:  Are circRNAs susceptible to degradation by RNase R?
# Query number 47 is:  What is the cause of the disease Xeroderma Pigmentosum?
# Query number 48 is:  Which is the "bonding hormone"?
# Query number 49 is:  Is the protein KCNQ2 associated with idiopathic epilepsy?
# Query number 50 is:  What particles is Hadron therapy using?
# Query number 51 is:  In clinical trials, the H3 R antagonist CEP-26401 has a positive effect on cognition, yes or no?
# Query number 52 is:  Which are the main NMD factors in Saccharomyces cerevisiae?
# Query number 53 is:  Of what origin is the MCF-7 cell line?
# Query number 54 is:  What is regioneR?
# Query number 55 is:  List pore forming toxins.
# Query number 56 is:  Between which types of DNA bases are mutational biases introduced due to directional mutation pressure?
# Query number 57 is:  What is the biological function of the SRY circular RNA (circRNA)?
# Query number 58 is:  Which algorithm has been developed for the automatic extraction of co-expressed gene clusters from gene expression data?
# Query number 59 is:  Name the phase 3 clinical trials for tofacitinib in colitis.
# Query number 60 is:  What part of the body is affected by mesotheliomia?
# Query number 61 is:  Which tool has been developed to identify the glycan shielding of glycosylated proteins?
# Query number 62 is:  Is the Fluzone intradermal and the Fluzone intradermal quadrivalent vaccine produced by different companies?
# Query number 63 is:  Is there a link between rare variants in PPARG and type 1 diabetes?
# Query number 64 is:  What is the proteoform?
# Query number 65 is:  What is known about the Kub5-Hera/RPRD1B interactome?
# Query number 66 is:  Matuzumab has been tested for treatment of which cancers?
# Query number 67 is:  Is creatinine assessment included in the MELD score?
# Query number 68 is:  Is arimoclomol a co-inducer of the heat shock response?
# Query number 69 is:  Is Mediator present at super enhancers?
# Query number 70 is:  Please list the difference between Pyoderma gangrenosum versus chronic venous ulceration?
# Query number 71 is:  Which siRNA based drug is in clinical trials for the treatment of pancreatic cancer?
# Query number 72 is:  Does GC content vary markedly within a given isochore?
# Query number 73 is:  is there an increase in ultrasound comets after intense exercise?
# Query number 74 is:  What is the role of Thyrotropin Releasing Hormone in the treatment of comatose patients?
# Query number 75 is:  What is the causative agent of the "Panama disease" affecting bananas?
# Query number 76 is:  Which receptor is targeted by Erenumab?
# Query number 77 is:  What is the function of circular RNA?
# Query number 78 is:  Which is the target of belimumab in Systemic Lupus Erythematosus treatment?
# Query number 79 is:  What is the genetic basis of the Delayed Sleep-Phase Syndrome (DSPS)?
# Query number 80 is:  Which method has been developed for assignment of enhancers to target genes?
# Query number 81 is:  Is physical performance influenced by thyroid hormone metabolism?
# Query number 82 is:  Are patients with marfan syndrome at increased risk of arrhythmias?
# Query number 83 is:  What is the function of CR elements in B-cells?
# Query number 84 is:  Which mutations in the cardiac isoform of the ryanodine receptor (RyR2) have been found to be related to CPVT?
# Query number 85 is:  Is Cystatin D a biomarker?
# Query number 86 is:  Which is the effect of the HP1a protein on chromatin?
# Query number 87 is:  The secreted frizzled-related protein 3 (sFPR3) is altered in human cancers.
# Are its level found to increase or to decrease?
# Query number 88 is:  Is Epistaxis associated with dental implant placement?
# Query number 89 is:  What is the vibrational theory of olfaction?
# Query number 90 is:  What is the role of the Ctf4-interacting-peptide or CIP-box?
# Query number 91 is:  Are conserved noncoding elements associated with developmental genes?
# Query number 92 is:  How is active neurotoxin of Clostridium botulinum detected?
# Query number 93 is:  What is the indication for isradipine?
# Query number 94 is:  What is the mode of inheritance of  long QT  Jervell and Lange-Nielsen syndrome?
# Query number 95 is:  Which genomic positions are preferentially selected for transposon insertion?
# Query number 96 is:  Is p100 the precursor protein molecule of the NF-kappaB transcription factor subunit p50?
# Query number 97 is:  What is the general function of H3K79 methylation?
# Query number 98 is:  List the core lung matrisome proteins.
# Query number 99 is:  What is the role of necroptosis in cancer therapy?
# Query number 100 is:  Which cytokine molecule activates SMADs?
# Query number 101 is:  Is adenosine signaling prognostic for cancer outcome?
# Query number 102 is:  Are TAD boundaries in Drosophila depleted in highly-expressed genes?
# Query number 103 is:  What happens to retrotransposons during ageing?
# Query number 104 is:  What is the role of TNF in obesity?
# Query number 105 is:  Name a method for enrichment of arginine-methylated peptides.
# Query number 106 is:  In which isochores are Alu elements enriched?
# Query number 107 is:  What is bimagrumab
# Query number 108 is:  Is Wnt16b secreted in response to chemotherapy?
# Query number 109 is:  Which class of genomic elements was assessed as part of the FANTOM6 project?
# Query number 110 is:  What is the suggested therapy for Mycobacterium avium infection?
# Query number 111 is:  What tissue is commonly affected in Marfan's syndrome
# Query number 112 is:  Which subcortical brain structure is influenced the most by common genetic variants?
# Query number 113 is:  Can ATAC-Seq be employed in single-cell mode?
# Query number 114 is:  Can exposure to heavy metals like lead(Pb) or cadmium(Cd) cause changes in DNA methylation patterns in Isoetes sinensis?
# Query number 115 is:  Which cells express CIDEC protein in humans?
# Query number 116 is:  What is the association between personality trait of neuroticism and risk for Alzheimer's disease?
# Query number 117 is:  Is protein CXCR4 used as a prognostic marker of cancer?
# Query number 118 is:  Is the NLM medical text indexer (MTI) still useful and relevant?
# Query number 119 is:  What does davunetide do to microtubules?
# Query number 120 is:  Describe Twiddler Syndrome.
# Query number 121 is:  What is Targeted Chromatin Capture (T2C)?
# Query number 122 is:  At which kind of individuals is pharmacological treatment of subclinical hypothyroidism effective in reducing cardiovascular events?
# Query number 123 is:  Are there any Decision support systems for chronic pain management ?
# Query number 124 is:  In which yeast chromosome does the rDNA cluster reside?
# Query number 125 is:  What is the Daughterless gene?
# Query number 126 is:  Does a linker histone exist in the yeast genome?
# Query number 127 is:  Is STAT3 transcription factor regulated by mTORC1?
# Query number 128 is:  What are the signatures of aggressive periodontitis?
# Query number 129 is:  Mutation of which gene causes arterial tortuosity syndrome?
# Query number 130 is:  Is it possible to visualize subtahalamic nucleus by using transcranial ultrasound?
# Query number 131 is:  What is Granzyme B?
# Query number 132 is:  What is drug target for olaparib?
# Query number 133 is:  What are chromones?
# Query number 134 is:  Which is the primary enzyme metabolizing esomeprazole?
# Query number 135 is:  Which drugs are included in the CAPOX chemotherapy regimen for colorectal cancer?
# Query number 136 is:  Describe PWMScan
# Query number 137 is:  What is the role of Gata3 in Th2 cells?
# Query number 138 is:  Where do the Schwann cells and melanocytes originate from?
# Query number 139 is:  What is another name for  keratomileusis?
# Query number 140 is:  Is Tuberous Sclerosis a genetic disease?
# Query number 141 is:  What was the predominant rotavirus genotype in the pre-vaccine era, in Australia?
# Query number 142 is:  Can doxycycline cause photosensitivity?
# Query number 143 is:  What is the mechanism of action of magrolimab?
# Query number 144 is:  The TRPM2 gene is associated with development of spontaneous thromboembolism?
# Query number 145 is:  Abnormality in which vertebral region is important in the Bertolotti's syndrome?
# Query number 146 is:  Which molecule is inhibited by ivosidenib?
# Query number 147 is:  Where does TDP43 localize in ALS neurons?
# Query number 148 is:  What is the cause of lactose intolerance?
# Query number 149 is:  What is the function of GFRAL?
# Query number 150 is:  List the results of mutated casein kinase 1 epsilon.
# Query number 151 is:  What is the phenomenon of gene kissing?
# Query number 152 is:  Which curated databases exist for spider-venom toxins?
# Query number 153 is:  Which disorders are associated to mutated Hepcidin (HAMP)?
# Query number 154 is:  What is the role of AMPK in diabetic cardiomyopathy?
# Query number 155 is:  Describe what is the usage of the Theatre software tool for genomic analysis.
# Query number 156 is:  Does nintedanib hold promise for lung disease associated with systemic sclerosis?
# Query number 157 is:  Does thyroid hormone affect cardiac remodeling ?
# Query number 158 is:  Which mutated enzyme is responsible for oculocutaneous 1 (OCA1)-type albinism?
# Query number 159 is:  Name siRNA drugs that have entered phase 2-3 clinical trials (by 2019).
# Query number 160 is:  What cellular process are okazaki fragments associated with?
# Query number 161 is:  Which protein is found to be mutated in Friedreich's ataxia?
# Query number 162 is:  What is the protein product of the gene GBA2?
# Query number 163 is:  What is the first line treatment for sarcoidosis?
# Query number 164 is:  What is the half-life of epimutations across generations of C. elegans?
# Query number 165 is:  Describe crowned dens syndrome.
# Query number 166 is:  Is Prochlorococcus the most abundant photosynthetic organism?
# Query number 167 is:  Is TREM2 associated with Alzheimer's disease in humans?
# Query number 168 is:  Describe the usefulness of the SPIKE database in human signaling pathways
# Query number 169 is:  What is the target of Volanesorsen?
# Query number 170 is:  Is there a sequence bias in MNase digestion patterns?
# Query number 171 is:  What is the results of inactivated ANGPLT3?
# Query number 172 is:  What is the mechanism of action of Lumasiran?
# Query number 173 is:  Is the microRNA 132 (miR-132) involved in brain pathologies?
# Query number 174 is:  Which portal has been developed to explore protein-protein interactions in cancer cell lines?
# Query number 175 is:  How does botulism toxin act on the muscle?
# Query number 176 is:  What colonoscopy findings have been reported in autism
# Query number 177 is:  Which bacteria causes rat bite fever?
# Query number 178 is:  What is the Barr body?
# Query number 179 is:  Which method has been developed for mapping of Transcription Start Sites (TSS) starting from nanograms of RNA?
# Query number 180 is:  Is L-4F an apoE mimetic peptide?
# Query number 181 is:  What is the use of emulsion PCR in Next Generation Sequencing?
# Query number 182 is:  What is the function of yeast Clr4 on chromatin?
# Query number 183 is:  Which two drugs are included in the Harvoni pill?
# Query number 184 is:  Is there a disease or condition called Exploding Head Syndrome?
# Query number 185 is:  Which cells produce Interleukin 17A?
# Query number 186 is:  Does Enzastaurin improve survival of glioblastoma patients?
# Query number 187 is:  What is a prolactinoma and where in the body would they be found?
# Query number 188 is:  Which drug was tested in the TEMSO Trial for multiple sclerosis?
# Query number 189 is:  Is Calcium homeostasis important in cardiac physiology and pathophysiology?
# Query number 190 is:  Does Yersinia pestis causes a respiratory infection?
# Query number 191 is:  Is the Apis mellifera genome available?
# Query number 192 is:  What is caused by a gain-of-function mutation in CLCN2?
# Query number 193 is:  Describe the Open Targets platform
# Query number 194 is:  What is the origin of XUT transcripts in yeast?
# Query number 195 is:  Does Serca2a bind PLN in the heart?
# Query number 196 is:  In which cells does TLR7 escape X-chromosome inactivation?
# Query number 197 is:  How many genes are in the gene signature screened by MammaPrint?
# Query number 198 is:  List Parkin binding partners
# Query number 199 is:  Has ubrogepant entered clinical phase III trials?
# Query number 200 is:  Which transcription factors are known as the four (4) "Yamanaka factors" that have been used to create induced pluripotent stem cells  (iPSCs)?
# Query number 201 is:  Is Tofacitinib effective for Ulcerative Colitis?
# Query number 202 is:  Which network analysis method can you use for prioritization of metabolic disease genes?
# Query number 203 is:  What is the association of estrogen replacement therapy and intracranial meningioma risk?
# Query number 204 is:  List signaling molecules (ligands) that interact with the receptor EGFR?
# Query number 205 is:  Is davunetide being considered for the treatment of progressive supranuclear palsy?
# Query number 206 is:  List the functions of the protein lactotransferrin.
# Query number 207 is:  Is there any role of TBR1 in autism?
# Query number 208 is:  Which main ribotype of Clostridium difficile is responsible of the recent outbreak?
# Query number 209 is:  Does Evolocumab improve cognitive function?
# Query number 210 is:  Which are the key players on radial glial specification to ependymal cells?
# Query number 211 is:  Clue cells are characteristics to which causative bacteria of vaginitis?
# Query number 212 is:  Which clotting factor is in the Andexxa?
# Query number 213 is:  Could plasmepsins be used as targets for developing anti-malaria drugs?
# Query number 214 is:  Which ApoE isoform is associated with atherosclerosis and Alzheimer's disease?
# Query number 215 is:  Are CpG islands located close to housekeeping genes?
# Query number 216 is:  What is the association between maternal and fetal alloantigens and RANTES production?
# Query number 217 is:  Does SARM1 deletion cause neurodegeneration?
# Query number 218 is:  List available biomedical question answering systems.
# Query number 219 is:  Does sphingosine-1 phosphoate suppress epiregulin?
# Query number 220 is:  Are OATP1B1 and OATP1B3 associated with bilirubin transport?
# Query number 221 is:  What is the function of Neu5Gc (N-Glycolylneuraminic acid)?
# Query number 222 is:  Which cancer is associated with increased levels of Serum alpha fetoprotein (AFP) ?
# Query number 223 is:  Please list the tests used to diagnose Allergic Rhinitis.
# Query number 224 is:  Describe CrossICC
# Query number 225 is:  CURB65 score is used for stratification of which disease?
# Query number 226 is:  Which conditions is caused by mutations in HFE?
# Query number 227 is:  Describe GREEKC
# Query number 228 is:  Which deep learning-based algorithms are used for enhancer prediction?
# Query number 229 is:  What body process does the Dentate Gyrus Mossy Cell control?
# Query number 230 is:  List off label uses for Rituximab.
# Query number 231 is:  Can leuprorelin acetate be used as androgen deprivation therapy?
# Query number 232 is:  List two most common symptoms of Aagenaes syndrome.
# Query number 233 is:  Do only changes in coding regions of MEF2C cause developmental disorders?
# Query number 234 is:  What is the mechanism of action of raxibacumab?
# List successfully written to evaluation/evaluation_metrics.csv

# %% [markdown]
# ### 2.2 Reranking of Initial Results from PubMed Entrez Search
#
# In this section, we will first retrieve the documents, embed their contents and the query, do a reranking of their order using cosine similarity between the embedded query and embedded document content, then output the re-ranked list and ground truth list.
#
# You can select whichever model you want to evaluate the reranking, but if you choose 'openai', please pass your api key as argument (api_key = 'your api key') into QueryExpansionManager(model_name, 'helper/descriptors.json').
#
# Note that there is no query expansion or suggestion at this stage.

# %%
from helper.config import api_key
# model_name = "sentence-transformers/all-mpnet-base-v2"
# model_name = "w601sxs/b1ade-embed"  
# model_name = "dmis-lab/biobert-v1.1"  
model_name = 'openai'
blade_embed_qe_manager = QueryExpansionManager(model_name, 'helper/descriptors.json', api_key=api_key)

with open ('evaluation/small subset.json') as infile:
    evaluation = json.load(infile)

retrieved_ids_list, ground_truth_list = get_initial_retrieved_and_ground_truth_docs(evaluation, remove_stop_words=False, articles_to_retrieve=10, qe_manager=blade_embed_qe_manager)
output_full_metrics_to_file(retrieved_ids_list, ground_truth_list, 'initial retrieval with Blade reranking, 10 articles, trimming', 'evaluation/evaluation_metrics.csv')
# Out:
# Query number 0 is:  What is the function of the AIRE gene at the embryonic stage?
# Query number 1 is:  Which type of analysis does DeSeq2 perform?
# Query number 2 is:  Which intraflagellar transport (IFT) motor protein has been linked to human skeletal ciliopathies?
# Query number 3 is:  Where in the body, is ghrelin secreted?
# Query number 4 is:  What is the effect of SAHA treatment in Huntington's disease?
# Query number 5 is:  What is membrane scission?
# Query number 6 is:  What is the color of the protein Ranasmurfin?
# Query number 7 is:  What is the mechanism of action of ocrelizumab for treatment of multiple sclerosis?
# Query number 8 is:  What treatment was studied in the KEYNOTE-522 trial?
# Query number 9 is:  Is Stat4 a transcription factor?
# Query number 10 is:  By which methods can we evaluate the reliability of a phylogenetic tree?
# Query number 11 is:  What is the physiological role of LKB1 involved in Peutz-Jeghers syndrome?
# Query number 12 is:  Is the Dictyostelium discoideum proteome known?
# Query number 13 is:  Which disease of the central nervous system is characterized by the presence of Lewy bodies?
# Query number 14 is:  What is the content of the METLIN database?
# Query number 15 is:  What is formin associated with in the snail?
# Query number 16 is:  Describe bigPint
# Query number 17 is:  What is the target of galcanezumab?
# Query number 18 is:  What is the mechanism of action of Vericiguat?
# Query number 19 is:  Is NicVAX vaccine effective for smoking cessation?
# Query number 20 is:  Which is the process that Conserved noncoding elements mostly regulate?
# Query number 21 is:  What is the effect of a defective CLN3 gene?
# Query number 22 is:  Are CTCF and BORIS involved in genome regulation and cancer?
# Query number 23 is:  Are there any statistical methods for normalizing and identifying differential regions in histone modification ChIP-seq data?
# Query number 24 is:  How is Slc22a3 imprinted?
# Query number 25 is:  Is selenocysteine an aminoacid?
# Query number 26 is:  Can adult humans be induced to produce fetal hemoglobin?
# Query number 27 is:  Which is the histone residue methylated by MLL1?
# Query number 28 is:  Which are the two main bacterial phyla in human gut?
# Query number 29 is:  Are cardenolides inhibitors of Na+/K+ ATPase?
# Query number 30 is:  Sweat Chloride Testing is used  for which disease?
# Query number 31 is:  Which gene is mutated in the Karak syndrome?
# Query number 32 is:  Does fibronectin constitute a serum biomarker for Duchenne muscular dystrophy?
# Query number 33 is:  Which gene-defect causes the Vel-blood type?
# Query number 34 is:  In which chromosome are transgenes inserted in the case of the LiPS-A3S line?
# Query number 35 is:  Which company developed Waylivra?
# Query number 36 is:  Which are the characteristics of  Andersen syndrome?
# Query number 37 is:  How effective is the dentritic cells treatment on cancer?
# Query number 38 is:  What is the typical rash associated with gluten ?
# Query number 39 is:  Which disease can be classified with the Awaji Criteria?
# Query number 40 is:  Is miR-21 related to carcinogenesis?
# Query number 41 is:  What is the mechanism of drug-induced gingival overgrowth?
# Query number 42 is:  What is known about depression in caregivers of brain tumor patients?
# Query number 43 is:  Describe CapSim
# Query number 44 is:  Is low T3 syndrome a prognostic marker in patients with renal insufficiency?
# Query number 45 is:  Is Bladder training an effective method to treat  urge incontinence ?
# Query number 46 is:  Are circRNAs susceptible to degradation by RNase R?
# Query number 47 is:  What is the cause of the disease Xeroderma Pigmentosum?
# Query number 48 is:  Which is the "bonding hormone"?
# Query number 49 is:  Is the protein KCNQ2 associated with idiopathic epilepsy?
# Query number 50 is:  What particles is Hadron therapy using?
# Query number 51 is:  In clinical trials, the H3 R antagonist CEP-26401 has a positive effect on cognition, yes or no?
# Query number 52 is:  Which are the main NMD factors in Saccharomyces cerevisiae?
# Query number 53 is:  Of what origin is the MCF-7 cell line?
# Query number 54 is:  What is regioneR?
# Query number 55 is:  List pore forming toxins.
# Query number 56 is:  Between which types of DNA bases are mutational biases introduced due to directional mutation pressure?
# Query number 57 is:  What is the biological function of the SRY circular RNA (circRNA)?
# Query number 58 is:  Which algorithm has been developed for the automatic extraction of co-expressed gene clusters from gene expression data?
# Query number 59 is:  Name the phase 3 clinical trials for tofacitinib in colitis.
# Query number 60 is:  What part of the body is affected by mesotheliomia?
# Query number 61 is:  Which tool has been developed to identify the glycan shielding of glycosylated proteins?
# Query number 62 is:  Is the Fluzone intradermal and the Fluzone intradermal quadrivalent vaccine produced by different companies?
# Query number 63 is:  Is there a link between rare variants in PPARG and type 1 diabetes?
# Query number 64 is:  What is the proteoform?
# Query number 65 is:  What is known about the Kub5-Hera/RPRD1B interactome?
# Query number 66 is:  Matuzumab has been tested for treatment of which cancers?
# Query number 67 is:  Is creatinine assessment included in the MELD score?
# Query number 68 is:  Is arimoclomol a co-inducer of the heat shock response?
# Query number 69 is:  Is Mediator present at super enhancers?
# Query number 70 is:  Please list the difference between Pyoderma gangrenosum versus chronic venous ulceration?
# Query number 71 is:  Which siRNA based drug is in clinical trials for the treatment of pancreatic cancer?
# Query number 72 is:  Does GC content vary markedly within a given isochore?
# Query number 73 is:  is there an increase in ultrasound comets after intense exercise?
# Query number 74 is:  What is the role of Thyrotropin Releasing Hormone in the treatment of comatose patients?
# Query number 75 is:  What is the causative agent of the "Panama disease" affecting bananas?
# Query number 76 is:  Which receptor is targeted by Erenumab?
# Query number 77 is:  What is the function of circular RNA?
# Query number 78 is:  Which is the target of belimumab in Systemic Lupus Erythematosus treatment?
# Query number 79 is:  What is the genetic basis of the Delayed Sleep-Phase Syndrome (DSPS)?
# Query number 80 is:  Which method has been developed for assignment of enhancers to target genes?
# Query number 81 is:  Is physical performance influenced by thyroid hormone metabolism?
# Query number 82 is:  Are patients with marfan syndrome at increased risk of arrhythmias?
# Query number 83 is:  What is the function of CR elements in B-cells?
# Query number 84 is:  Which mutations in the cardiac isoform of the ryanodine receptor (RyR2) have been found to be related to CPVT?
# Query number 85 is:  Is Cystatin D a biomarker?
# Query number 86 is:  Which is the effect of the HP1a protein on chromatin?
# Query number 87 is:  The secreted frizzled-related protein 3 (sFPR3) is altered in human cancers.
# Are its level found to increase or to decrease?
# Query number 88 is:  Is Epistaxis associated with dental implant placement?
# Query number 89 is:  What is the vibrational theory of olfaction?
# Query number 90 is:  What is the role of the Ctf4-interacting-peptide or CIP-box?
# Query number 91 is:  Are conserved noncoding elements associated with developmental genes?
# Query number 92 is:  How is active neurotoxin of Clostridium botulinum detected?
# Query number 93 is:  What is the indication for isradipine?
# Query number 94 is:  What is the mode of inheritance of  long QT  Jervell and Lange-Nielsen syndrome?
# Query number 95 is:  Which genomic positions are preferentially selected for transposon insertion?
# Query number 96 is:  Is p100 the precursor protein molecule of the NF-kappaB transcription factor subunit p50?
# Query number 97 is:  What is the general function of H3K79 methylation?
# Query number 98 is:  List the core lung matrisome proteins.
# Query number 99 is:  What is the role of necroptosis in cancer therapy?
# Query number 100 is:  Which cytokine molecule activates SMADs?
# Query number 101 is:  Is adenosine signaling prognostic for cancer outcome?
# Query number 102 is:  Are TAD boundaries in Drosophila depleted in highly-expressed genes?
# Query number 103 is:  What happens to retrotransposons during ageing?
# Query number 104 is:  What is the role of TNF in obesity?
# Query number 105 is:  Name a method for enrichment of arginine-methylated peptides.
# Query number 106 is:  In which isochores are Alu elements enriched?
# Query number 107 is:  What is bimagrumab
# Query number 108 is:  Is Wnt16b secreted in response to chemotherapy?
# Query number 109 is:  Which class of genomic elements was assessed as part of the FANTOM6 project?
# Query number 110 is:  What is the suggested therapy for Mycobacterium avium infection?
# Query number 111 is:  What tissue is commonly affected in Marfan's syndrome
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\Vincent Chong Yi Qin\Documents\GitHub\Information-Retrieval\.venv\Lib\site-packages\urllib3\connection.py:196, in HTTPConnection._new_conn(self)
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#
# File c:\Users\Vincent Chong Yi Qin\Documents\GitHub\Information-Retrieval\.venv\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File c:\Users\Vincent Chong Yi Qin\Documents\GitHub\Information-Retrieval\.venv\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File c:\Users\Vincent Chong Yi Qin\Documents\GitHub\Information-Retrieval\.venv\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File c:\Users\Vincent Chong Yi Qin\Documents\GitHub\Information-Retrieval\.venv\Lib\site-packages\urllib3\connectionpool.py:490, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     489         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 490     raise new_e
#     492 # conn.request() calls http.client.*.request, not the method in
#     493 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File c:\Users\Vincent Chong Yi Qin\Documents\GitHub\Information-Retrieval\.venv\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
# --> 466     self._validate_conn(conn)
#     467 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\Users\Vincent Chong Yi Qin\Documents\GitHub\Information-Retrieval\.venv\Lib\site-packages\urllib3\connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File c:\Users\Vincent Chong Yi Qin\Documents\GitHub\Information-Retrieval\.venv\Lib\site-packages\urllib3\connection.py:615, in HTTPSConnection.connect(self)
#     614 sock: socket.socket | ssl.SSLSocket
# --> 615 self.sock = sock = self._new_conn()
#     616 server_hostname: str = self.host
#
# File c:\Users\Vincent Chong Yi Qin\Documents\GitHub\Information-Retrieval\.venv\Lib\site-packages\urllib3\connection.py:205, in HTTPConnection._new_conn(self)
#     204 except SocketTimeout as e:
# --> 205     raise ConnectTimeoutError(
#     206         self,
#     207         f"Connection to {self.host} timed out. (connect timeout={self.timeout})",
#     208     ) from e
#     210 except OSError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x0000016BEDF5E310>, 'Connection to eutils.ncbi.nlm.nih.gov timed out. (connect timeout=None)')
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\Vincent Chong Yi Qin\Documents\GitHub\Information-Retrieval\.venv\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File c:\Users\Vincent Chong Yi Qin\Documents\GitHub\Information-Retrieval\.venv\Lib\site-packages\urllib3\connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File c:\Users\Vincent Chong Yi Qin\Documents\GitHub\Information-Retrieval\.venv\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='eutils.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /entrez/eutils/efetch.fcgi?db=pubmed&id=39171136%2C39129620%2C37750650%2C37082918%2C36605074%2C35463710%2C32950946%2C32824919%2C29430308%2C28243770&retmode=xml&rettype=abstract (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000016BEDF5E310>, 'Connection to eutils.ncbi.nlm.nih.gov timed out. (connect timeout=None)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# Cell In[49], line 11
#       8 with open ('evaluation/small subset.json') as infile:
#       9     evaluation = json.load(infile)
# ---> 11 retrieved_ids_list, ground_truth_list = get_initial_retrieved_and_ground_truth_docs(evaluation, remove_stop_words=False, articles_to_retrieve=10, qe_manager=blade_embed_qe_manager)
#      12 output_full_metrics_to_file(retrieved_ids_list, ground_truth_list, 'initial retrieval with Blade reranking, 10 articles, trimming', 'evaluation/evaluation_metrics.csv')
#
# Cell In[46], line 36, in get_initial_retrieved_and_ground_truth_docs(evaluation_set, remove_stop_words, articles_to_retrieve, qe_manager)
#      34 if qe_manager is not None:
#      35     ranking_list = []
# ---> 36     retrieved_article_details = pubs.get_article_details_from_id(retrieved_ids)
#      37     for key, value in retrieved_article_details.items():
#      38         title = value.get('Title') or ""
#
# File c:\Users\Vincent Chong Yi Qin\Documents\GitHub\Information-Retrieval\helper\pubmed_search.py:229, in get_article_details_from_id(id_list, important_headings_only)
#     221 efetch_params = {
#     222     "db": "pubmed",
#     223     "id": ",".join(id_list),        # Join PMIDs with commas
#     224     "retmode": "xml",               # Request XML format for easier parsing
#     225     "rettype": "abstract"           # Request abstract type
#     226 }
#     228 # Send the EFetch request
# --> 229 efetch_response = requests.get(efetch_url, params=efetch_params)
#     231 if efetch_response.status_code == 200:
#     232     root = ET.fromstring(efetch_response.content)
#
# File c:\Users\Vincent Chong Yi Qin\Documents\GitHub\Information-Retrieval\.venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Vincent Chong Yi Qin\Documents\GitHub\Information-Retrieval\.venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Vincent Chong Yi Qin\Documents\GitHub\Information-Retrieval\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Vincent Chong Yi Qin\Documents\GitHub\Information-Retrieval\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Vincent Chong Yi Qin\Documents\GitHub\Information-Retrieval\.venv\Lib\site-packages\requests\adapters.py:688, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     685 if isinstance(e.reason, ConnectTimeoutError):
#     686     # TODO: Remove this in 3.0.0: see #2811
#     687     if not isinstance(e.reason, NewConnectionError):
# --> 688         raise ConnectTimeout(e, request=request)
#     690 if isinstance(e.reason, ResponseError):
#     691     raise RetryError(e, request=request)
#
# ConnectTimeout: HTTPSConnectionPool(host='eutils.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /entrez/eutils/efetch.fcgi?db=pubmed&id=39171136%2C39129620%2C37750650%2C37082918%2C36605074%2C35463710%2C32950946%2C32824919%2C29430308%2C28243770&retmode=xml&rettype=abstract (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000016BEDF5E310>, 'Connection to eutils.ncbi.nlm.nih.gov timed out. (connect timeout=None)'))

# %% [markdown]
# # 3. Evaluation for Query Expansion and Suggestion

# %%
import pandas as pd
import helper.pubmed_search as pubs

def get_reretrieval_and_ground_truth_docs(evaluation_set, qe_manager):
    retrieved_ids_list = []
    ground_truth_list = []
    # Run it through the system:
    for idx, entry in enumerate(evaluation_set):
        # # for diagnostics only
        # if idx > 0:
        #     continue
        query = entry['body']      
        # When running the evaluation, there is a tendency for the internet to break so we need to continuously try to connnect
        # rerun = True
        runs = 0
        while True:
            # query the question through the database and extract the relevant documents
            try:
                print('Query number', idx, 'is: ', query)
                ground_truth = [x.split('/')[-1] for x in entry['documents']]  
                ground_truth_length = len(ground_truth)                    

                # Get the initial round of documents
                heading_entries, article_entries = qe_manager.get_entries_from_query(query)  
                title_abstract_threshold = 20 
                heading_threshold = 40   
                
                print('Initial article length:', len(article_entries))
                # Deal with articles
                if article_entries!=[]:
                    article_entries_df = pd.DataFrame(article_entries).drop_duplicates(['name']).sort_values(by=['suitability'], ascending=False)  
                    # print('Initial article length:', len(article_entries_df))
                    article_entries_df.to_csv('evaluation/article_entries.csv')
                    filtered_article_entries = article_entries_df[article_entries_df['suitability'] > title_abstract_threshold].to_dict(orient='records')  
                else:
                    retrieved_ids_list.append([])
                    print('Benchmark length is:', ground_truth_length)
                    ground_truth_list.append(ground_truth) 
                    break # if no articles returned, move on

                if heading_entries!=[]:
                    heading_entries_df = pd.DataFrame(heading_entries).drop_duplicates(['name']).sort_values(by=['suitability'], ascending=False) 
                    heading_entries_df.to_csv('evaluation/heading_entries.csv')
                    filtered_heading_entries = heading_entries_df[heading_entries_df['suitability'] > heading_threshold].to_dict(orient='records')    
                
                requery = pubs.create_semantic_neighbourhood_query(filtered_heading_entries, filtered_article_entries)
                print('Re-Query is: ', requery)
                if requery != '':
                    _, requeried_article_entries = qe_manager.get_entries_from_query(requery, requery = True, articles_to_retrieve = 20) 
                else:
                    requeried_article_entries = []
                
                print('Initial requery length is:', len(requeried_article_entries))
                # And finally, get the list of retrieved_ids to be returned
                if (requeried_article_entries != []) and (article_entries != []):
                    requeried_article_entries_df = pd.DataFrame(requeried_article_entries)
                    requeried_article_entries_df.to_csv('evaluation/requeried_article_entries.csv')
                    combined_article_entries_df = pd.concat([article_entries_df, requeried_article_entries_df]).drop_duplicates(['name']).sort_values(by=['suitability'], ascending=False)
                    combined_article_entries_df.to_csv('evaluation/combined_article_entries_df.csv')                    
                    retrieved_ids = combined_article_entries_df.head(ground_truth_length)['name'].to_list()
                    # The following code ensures length of retrieved ids are same as ground truth
                    if len(retrieved_ids) < ground_truth_length:
                        entries_to_add = ground_truth_length - len(retrieved_ids)
                        for i in range (entries_to_add):
                            retrieved_ids.append('')
                elif article_entries != []: # if there are no articles in initially retrieved set, there won't be requeried articles as well
                    retrieved_ids = article_entries_df.head(ground_truth_length)['name'].to_list()
                    if len(retrieved_ids) < ground_truth_length:
                        entries_to_add = ground_truth_length - len(retrieved_ids)
                        for i in range (entries_to_add):
                            retrieved_ids.append('')
                else: # this one should be handled earlier but we put another here just for safety
                    retrieved_ids = []
                retrieved_ids_list.append(retrieved_ids)
                ground_truth_list.append(ground_truth) 
                print('Length of retrieved list: ', len(retrieved_ids))
                print('Ground truth length is:', ground_truth_length)
                break # once information is extracted, stop the rerun                
            # This is just to pre-ampt anything that would happen above during long evaluation runs.
            except Exception as e:
                print('Error occured when querying pubmed:', e)
                runs +=1
                if runs > 3: # after 10 rounds of rerun due to errors, just move on
                    print('This entry is not counted:', entry['body'])
                    break 
    return retrieved_ids_list, ground_truth_list

# %%
from helper.pubmed_search import QueryExpansionManager  
import json 

# model_name1 = "sentence-transformers/all-mpnet-base-v2"
# model_name = "w601sxs/b1ade-embed"  
model_name = "dmis-lab/biobert-v1.1" 
blade_embed_qe_manager = QueryExpansionManager(model_name, 'helper/descriptors.json')

# from helper.config import api_key
# blade_embed_qe_manager = QueryExpansionManager('openai', 'helper/descriptors.json', api_key)

# with open ('evaluation/subset.json') as infile:
#     evaluation = json.load(infile)
with open ('evaluation/small subset.json') as infile:
    evaluation = json.load(infile)
    
# pure retrieval on a fixed dataset (takes 31.7s compared to retrieval + p@k ranking at 33.3s)
retrieved_ids_list, ground_truth_list = get_reretrieval_and_ground_truth_docs(evaluation, blade_embed_qe_manager)
output_full_metrics_to_file(retrieved_ids_list, ground_truth_list, 'biobert (re retrieval, 10 articles retrieved, no reranking, 233 documents) trimming', 'evaluation/evaluation_metrics.csv')
# Out:
# c:\Users\Vincent Chong Yi Qin\Documents\GitHub\Biomedical-Information-Retrieval\.venv\Lib\site-packages\huggingface_hub\file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Query number 0 is:  What is the function of the AIRE gene at the embryonic stage?
# Initial article length: 9
# Re-Query is:  ("Cell Proliferation"[MeSH Terms] ) OR ("Gene Expression Regulation, Developmental"[MeSH Terms] ) OR ("Thymus Gland"[MeSH Terms] AND "Epithelial Cells"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  5
# Ground truth length is: 5
# Query number 1 is:  Which type of analysis does DeSeq2 perform?
# Initial article length: 10
# Re-Query is:  ("Papillomavirus Infections"[MeSH Terms] AND "Head and Neck Neoplasms"[MeSH Terms] AND "MicroRNAs"[MeSH Terms] ) OR ("Endogenous Retroviruses"[MeSH Terms] AND "Leukocytes, Mononuclear"[MeSH Terms] AND "B-Lymphocytes"[MeSH Terms] AND "Antibodies, Monoclonal, Humanized"[MeSH Terms] ) OR ("Arthropod Antennae"[MeSH Terms] AND "Gene Expression Profiling"[MeSH Terms] AND "Calliphoridae"[MeSH Terms] ) OR ("Fontan Procedure"[MeSH Terms] AND "Liver Diseases"[MeSH Terms] AND "Heart Defects, Congenital"[MeSH Terms] ) OR ("Diabetes Mellitus, Type 2"[MeSH Terms] AND "Diabetic Neuropathies"[MeSH Terms] ) OR ("Breast Neoplasms"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  15
# Ground truth length is: 15
# Query number 2 is:  Which intraflagellar transport (IFT) motor protein has been linked to human skeletal ciliopathies?
# Initial article length: 2
# Re-Query is:
# Initial requery length is: 0
# Length of retrieved list:  4
# Ground truth length is: 4
# Query number 3 is:  Where in the body, is ghrelin secreted?
# Initial article length: 10
# Re-Query is:  ("Ghrelin"[MeSH Terms] AND "Receptors, Ghrelin"[MeSH Terms] ) OR ("Ghrelin"[MeSH Terms] AND "PPAR gamma"[MeSH Terms] AND "Rats, Wistar"[MeSH Terms] AND "Signal Transduction"[MeSH Terms] AND "Liver"[MeSH Terms] AND "Insulin"[MeSH Terms] AND "Diglycerides"[MeSH Terms] ) OR ("Insulin-Like Growth Factor I"[MeSH Terms] AND "Ghrelin"[MeSH Terms] ) OR ("Exercise"[MeSH Terms] ) OR ("Appetite"[MeSH Terms] AND "Stress, Physiological"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  18
# Ground truth length is: 18
# Query number 4 is:  What is the effect of SAHA treatment in Huntington's disease?
# Initial article length: 10
# Re-Query is:  ("Signal Transduction"[MeSH Terms] ) OR ("Epigenesis, Genetic"[MeSH Terms] ) OR ("Neurodegenerative Diseases"[MeSH Terms] AND "Alzheimer Disease"[MeSH Terms] AND "Neuroprotective Agents"[MeSH Terms] ) OR ("Drug Discovery"[MeSH Terms] ) OR ("Ethnopharmacology"[MeSH Terms] AND "Withania"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  4
# Ground truth length is: 4
# Query number 5 is:  What is membrane scission?
# Initial article length: 10
# Re-Query is:  ("Arabidopsis"[MeSH Terms] AND "Autophagosomes"[MeSH Terms] AND "Endosomal Sorting Complexes Required for Transport"[MeSH Terms] AND "Arabidopsis Proteins"[MeSH Terms] AND "Calcium-Binding Proteins"[MeSH Terms] AND "Autophagy"[MeSH Terms] ) OR ("Actins"[MeSH Terms] AND "Axons"[MeSH Terms] AND "Clathrin"[MeSH Terms] AND "Endocytosis"[MeSH Terms] AND "Spectrin"[MeSH Terms] ) OR ("SARS-CoV-2"[MeSH Terms] AND "Virus Internalization"[MeSH Terms] AND "COVID-19"[MeSH Terms] AND "Endosomes"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  15
# Ground truth length is: 15
# Query number 6 is:  What is the color of the protein Ranasmurfin?
# Initial article length: 2
# Re-Query is:  ("Proteome"[MeSH Terms] ) OR ("Anura"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  2
# Ground truth length is: 2
# Query number 7 is:  What is the mechanism of action of ocrelizumab for treatment of multiple sclerosis?
# Initial article length: 10
# Re-Query is:  ("Antibodies, Monoclonal, Humanized"[MeSH Terms] AND "Immunologic Factors"[MeSH Terms] AND "Enteritis"[MeSH Terms] ) OR ("Antibodies, Monoclonal, Humanized"[MeSH Terms] AND "Alemtuzumab"[MeSH Terms] AND "Immunologic Factors"[MeSH Terms] ) OR ("Antibodies, Monoclonal, Humanized"[MeSH Terms] AND "Multiple Sclerosis, Chronic Progressive"[MeSH Terms] AND "Immunologic Factors"[MeSH Terms] ) OR ("Multiple Sclerosis, Relapsing-Remitting"[MeSH Terms] AND "Cladribine"[MeSH Terms] AND "Alemtuzumab"[MeSH Terms] AND "Fingolimod Hydrochloride"[MeSH Terms] AND "Natalizumab"[MeSH Terms] AND "Antibodies, Monoclonal, Humanized"[MeSH Terms] AND "Immunosuppressive Agents"[MeSH Terms] ) OR ("Multiple Sclerosis"[MeSH Terms] AND "COVID-19"[MeSH Terms] ) OR ("Natalizumab"[MeSH Terms] AND "Antibodies, Monoclonal, Humanized"[MeSH Terms] AND "Disease Progression"[MeSH Terms] AND "Immunologic Factors"[MeSH Terms] ) OR ("Antibodies, Monoclonal, Humanized"[MeSH Terms] AND "Multiple Sclerosis, Relapsing-Remitting"[MeSH Terms] ) OR ("Fingolimod Hydrochloride"[MeSH Terms] AND "Magnetic Resonance Imaging"[MeSH Terms] AND "Antibodies, Monoclonal, Humanized"[MeSH Terms] ) OR ("Natalizumab"[MeSH Terms] AND "Multiple Sclerosis, Relapsing-Remitting"[MeSH Terms] AND "Immunologic Factors"[MeSH Terms] AND "Leukoencephalopathy, Progressive Multifocal"[MeSH Terms] AND "JC Virus"[MeSH Terms] ) OR ("Protein Kinase C beta"[MeSH Terms] AND "Multiple Sclerosis"[MeSH Terms] AND "Antibodies, Monoclonal, Humanized"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  20
# Ground truth length is: 20
# Query number 8 is:  What treatment was studied in the KEYNOTE-522 trial?
# Initial article length: 1
# Re-Query is:  ("Triple Negative Breast Neoplasms"[MeSH Terms] AND "Vaccines"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  6
# Ground truth length is: 6
# Query number 9 is:  Is Stat4 a transcription factor?
# Initial article length: 10
# Re-Query is:  ("Interleukin-12"[MeSH Terms] AND "Cell Differentiation"[MeSH Terms] AND "T-Lymphocytes, Regulatory"[MeSH Terms] ) OR ("STAT4 Transcription Factor"[MeSH Terms] AND "Dendritic Cells"[MeSH Terms] AND "Interleukin-23"[MeSH Terms] AND "Encephalomyelitis, Autoimmune, Experimental"[MeSH Terms] AND "Signal Transduction"[MeSH Terms] ) OR ("Piperidines"[MeSH Terms] AND "Pyrimidines"[MeSH Terms] AND "Rosacea"[MeSH Terms] AND "Signal Transduction"[MeSH Terms] ) OR ("STAT4 Transcription Factor"[MeSH Terms] AND "Lupus Erythematosus, Systemic"[MeSH Terms] AND "Genetic Predisposition to Disease"[MeSH Terms] AND "Interferon Regulatory Factors"[MeSH Terms] AND "Asian People"[MeSH Terms] AND "Genome-Wide Association Study"[MeSH Terms] AND "Interferon Type I"[MeSH Terms] ) OR ("STAT4 Transcription Factor"[MeSH Terms] AND "Myocardial Reperfusion Injury"[MeSH Terms] AND "Proto-Oncogene Proteins c-akt"[MeSH Terms] AND "Phosphatidylinositol 3-Kinases"[MeSH Terms] AND "Signal Transduction"[MeSH Terms] AND "Apoptosis"[MeSH Terms] ) OR ("Immune Checkpoint Inhibitors"[MeSH Terms] AND "Tumor Microenvironment"[MeSH Terms] AND "Neoplasms"[MeSH Terms] ) OR ("Diet, High-Fat"[MeSH Terms] AND "Interleukin-6"[MeSH Terms] AND "Arrhythmias, Cardiac"[MeSH Terms] AND "Signal Transduction"[MeSH Terms] AND "STAT4 Transcription Factor"[MeSH Terms] ) OR ("Carcinoma, Renal Cell"[MeSH Terms] AND "Kidney Neoplasms"[MeSH Terms] AND "Biomarkers, Tumor"[MeSH Terms] AND "Signal Transduction"[MeSH Terms] AND "Immunotherapy"[MeSH Terms] AND "Gene Expression Regulation, Neoplastic"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  4
# Ground truth length is: 4
# Query number 10 is:  By which methods can we evaluate the reliability of a phylogenetic tree?
# Initial article length: 10
# Re-Query is:  ("Phylogeny"[MeSH Terms] AND "Software"[MeSH Terms] ) OR ("Phylogeny"[MeSH Terms] AND "Myrtaceae"[MeSH Terms] ) OR ("Phylogeny"[MeSH Terms] AND "Software"[MeSH Terms] AND "Algorithms"[MeSH Terms] ) OR ("DNA Barcoding, Taxonomic"[MeSH Terms] AND "Electron Transport Complex IV"[MeSH Terms] ) OR ("Olea"[MeSH Terms] AND "Genetic Variation"[MeSH Terms] AND "Microsatellite Repeats"[MeSH Terms] ) OR ("Aedes"[MeSH Terms] AND "DNA Barcoding, Taxonomic"[MeSH Terms] AND "Genetic Variation"[MeSH Terms] AND "Phylogeny"[MeSH Terms] AND "Mosquito Vectors"[MeSH Terms] ) OR ("Genome, Chloroplast"[MeSH Terms] AND "Phylogeny"[MeSH Terms] AND "Asteraceae"[MeSH Terms] ) OR ("Haemophilus influenzae"[MeSH Terms] AND "Multilocus Sequence Typing"[MeSH Terms] AND "Phylogeny"[MeSH Terms] AND "Genome, Bacterial"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  13
# Ground truth length is: 13
# Query number 11 is:  What is the physiological role of LKB1 involved in Peutz-Jeghers syndrome?
# Initial article length: 2
# Re-Query is:
# Initial requery length is: 0
# Length of retrieved list:  1
# Ground truth length is: 1
# Query number 12 is:  Is the Dictyostelium discoideum proteome known?
# Initial article length: 10
# Re-Query is:  ("Dictyostelium"[MeSH Terms] ) OR ("Dictyostelium"[MeSH Terms] AND "Cell Movement"[MeSH Terms] ) OR ("Databases, Protein"[MeSH Terms] AND "Protein Folding"[MeSH Terms] AND "Software"[MeSH Terms] ) OR ("Antimalarials"[MeSH Terms] AND "Hexanones"[MeSH Terms] AND "Plasmodium falciparum"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  9
# Ground truth length is: 9
# Query number 13 is:  Which disease of the central nervous system is characterized by the presence of Lewy bodies?
# Initial article length: 10
# Re-Query is:  ("Parkinson Disease"[MeSH Terms] ) OR ("alpha-Synuclein"[MeSH Terms] AND "Brain"[MeSH Terms] AND "Cryoelectron Microscopy"[MeSH Terms] AND "Lewy Body Disease"[MeSH Terms] AND "Brain Chemistry"[MeSH Terms] ) OR ("Parkinson Disease"[MeSH Terms] ) OR ("Parkinson Disease"[MeSH Terms] AND "Neurodegenerative Diseases"[MeSH Terms] AND "Synucleinopathies"[MeSH Terms] ) OR ("Lewy Body Disease"[MeSH Terms] AND "Multiple System Atrophy"[MeSH Terms] AND "Parkinson Disease"[MeSH Terms] AND "Synucleinopathies"[MeSH Terms] ) OR ("Parkinson Disease"[MeSH Terms] AND "Neurodegenerative Diseases"[MeSH Terms] AND "Mitochondrial Diseases"[MeSH Terms] ) OR ("alpha-Synuclein"[MeSH Terms] AND "Aptamers, Nucleotide"[MeSH Terms] AND "Parkinson Disease"[MeSH Terms] AND "Synucleinopathies"[MeSH Terms] ) OR ("Microglia"[MeSH Terms] AND "alpha-Synuclein"[MeSH Terms] AND "Receptors, Granulocyte-Macrophage Colony-Stimulating Factor"[MeSH Terms] AND "Rats, Inbred F344"[MeSH Terms] ) OR ("Parkinson Disease"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  17
# Ground truth length is: 17
# Query number 14 is:  What is the content of the METLIN database?
# Initial article length: 8
# Re-Query is:  ("Databases, Factual"[MeSH Terms] ) OR ("Plants, Medicinal"[MeSH Terms] AND "Polygonatum"[MeSH Terms] ) OR ("Citrus"[MeSH Terms] ) OR ("Chromatography, High Pressure Liquid"[MeSH Terms] AND "Metabolome"[MeSH Terms] AND "Tandem Mass Spectrometry"[MeSH Terms] ) OR ("Beer"[MeSH Terms] AND "Probiotics"[MeSH Terms] ) OR ("Mass Spectrometry"[MeSH Terms] ) OR ("Metabolome"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  17
# Ground truth length is: 17
# Query number 15 is:  What is formin associated with in the snail?
# Initial article length: 3
# Re-Query is:  ("Body Patterning"[MeSH Terms] AND "Signal Transduction"[MeSH Terms] ) OR ("Epithelial-Mesenchymal Transition"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  1
# Ground truth length is: 1
# Query number 16 is:  Describe bigPint
# Initial article length: 0
# Benchmark length is: 1
# Query number 17 is:  What is the target of galcanezumab?
# Initial article length: 10
# Re-Query is:  ("Migraine Disorders"[MeSH Terms] AND "Calcitonin Gene-Related Peptide"[MeSH Terms] AND "Antibodies, Monoclonal, Humanized"[MeSH Terms] AND "Sexual Dysfunction, Physiological"[MeSH Terms] ) OR ("Cluster Headache"[MeSH Terms] ) OR ("Calcitonin Gene-Related Peptide"[MeSH Terms] AND "Migraine Disorders"[MeSH Terms] AND "Piperidines"[MeSH Terms] AND "Pyridines"[MeSH Terms] AND "Pyrroles"[MeSH Terms] AND "Spiro Compounds"[MeSH Terms] ) OR ("Calcitonin Gene-Related Peptide"[MeSH Terms] AND "Migraine Disorders"[MeSH Terms] AND "Piperidines"[MeSH Terms] AND "Pyridines"[MeSH Terms] AND "Pyrroles"[MeSH Terms] AND "Spiro Compounds"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  16
# Ground truth length is: 16
# Query number 18 is:  What is the mechanism of action of Vericiguat?
# Initial article length: 10
# Re-Query is:  ("Heart Failure"[MeSH Terms] AND "Stroke Volume"[MeSH Terms] AND "Pyrimidines"[MeSH Terms] AND "Hemodynamics"[MeSH Terms] ) OR ("Fabry Disease"[MeSH Terms] AND "Heterocyclic Compounds, 2-Ring"[MeSH Terms] AND "Pyrimidines"[MeSH Terms] ) OR ("Heart Failure"[MeSH Terms] AND "Stroke Volume"[MeSH Terms] ) OR ("Heart Failure"[MeSH Terms] AND "Hospitalization"[MeSH Terms] ) OR ("Heart Failure, Systolic"[MeSH Terms] AND "Drug Therapy, Combination"[MeSH Terms] AND "Natriuretic Peptide, Brain"[MeSH Terms] ) OR ("Heart Failure"[MeSH Terms] ) OR ("Ivabradine"[MeSH Terms] AND "Heart Failure"[MeSH Terms] AND "Stroke Volume"[MeSH Terms] AND "Drug Therapy, Combination"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  19
# Ground truth length is: 19
# Query number 19 is:  Is NicVAX vaccine effective for smoking cessation?
# Initial article length: 10
# Re-Query is:  ("Cues"[MeSH Terms] ) OR ("Bioethics"[MeSH Terms] AND "Smoking Prevention"[MeSH Terms] ) OR ("Smoking Prevention"[MeSH Terms] ) OR ("Smoking Prevention"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  5
# Ground truth length is: 5
# Query number 20 is:  Which is the process that Conserved noncoding elements mostly regulate?
# Initial article length: 10
# Re-Query is:  ("Retroelements"[MeSH Terms] AND "Evolution, Molecular"[MeSH Terms] AND "Gene Silencing"[MeSH Terms] ) OR ("Phylogeny"[MeSH Terms] AND "Evolution, Molecular"[MeSH Terms] AND "Models, Genetic"[MeSH Terms] ) OR ("Fruit"[MeSH Terms] AND "Gene Expression Regulation, Plant"[MeSH Terms] AND "Conserved Sequence"[MeSH Terms] ) OR ("Stress, Physiological"[MeSH Terms] AND "Gene Expression Regulation, Plant"[MeSH Terms] AND "Arabidopsis"[MeSH Terms] AND "Promoter Regions, Genetic"[MeSH Terms] AND "Photosynthesis"[MeSH Terms] AND "Plants, Genetically Modified"[MeSH Terms] ) OR ("Chromatin Assembly and Disassembly"[MeSH Terms] AND "Regulatory Sequences, Nucleic Acid"[MeSH Terms] ) OR ("Apoferritins"[MeSH Terms] AND "T-Lymphocytes, Regulatory"[MeSH Terms] ) OR ("MicroRNAs"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  17
# Ground truth length is: 17
# Query number 21 is:  What is the effect of a defective CLN3 gene?
# Initial article length: 10
# Re-Query is:  ("Genetic Pleiotropy"[MeSH Terms] ) OR ("PPAR alpha"[MeSH Terms] AND "Neuronal Ceroid-Lipofuscinoses"[MeSH Terms] ) OR ("Adaptation, Physiological"[MeSH Terms] AND "Oncogenes"[MeSH Terms] ) OR ("Gene Expression"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  9
# Ground truth length is: 9
# Query number 22 is:  Are CTCF and BORIS involved in genome regulation and cancer?
# Initial article length: 10
# Re-Query is:  ("Alternative Splicing"[MeSH Terms] ) OR ("Gene Expression Regulation, Neoplastic"[MeSH Terms] AND "Repressor Proteins"[MeSH Terms] ) OR ("DNA Methylation"[MeSH Terms] ) OR ("Epigenesis, Genetic"[MeSH Terms] AND "Gene Expression Regulation, Neoplastic"[MeSH Terms] ) OR ("DNA Methylation"[MeSH Terms] AND "Promoter Regions, Genetic"[MeSH Terms] ) OR ("Gene Expression Regulation, Neoplastic"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  8
# Ground truth length is: 8
# Query number 23 is:  Are there any statistical methods for normalizing and identifying differential regions in histone modification ChIP-seq data?
# Initial article length: 3
# Re-Query is:  ("Models, Statistical"[MeSH Terms] ) OR ("Histones"[MeSH Terms] AND "Models, Theoretical"[MeSH Terms] AND "Peptide Library"[MeSH Terms] AND "Software"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  1
# Ground truth length is: 1
# Query number 24 is:  How is Slc22a3 imprinted?
# Initial article length: 0
# Benchmark length is: 7
# Query number 25 is:  Is selenocysteine an aminoacid?
# Initial article length: 10
# Re-Query is:  ("Ferroptosis"[MeSH Terms] AND "Selenium"[MeSH Terms] AND "Iron"[MeSH Terms] AND "Phospholipid Hydroperoxide Glutathione Peroxidase"[MeSH Terms] AND "Peroxiredoxin VI"[MeSH Terms] ) OR ("Selenocysteine"[MeSH Terms] AND "Peptides"[MeSH Terms] ) OR ("Selenium"[MeSH Terms] AND "Selenoproteins"[MeSH Terms] ) OR ("Nerve Regeneration"[MeSH Terms] AND "Selenocysteine"[MeSH Terms] AND "Rats, Sprague-Dawley"[MeSH Terms] AND "Schwann Cells"[MeSH Terms] AND "Oxidative Stress"[MeSH Terms] AND "Sciatic Nerve"[MeSH Terms] AND "Selenium"[MeSH Terms] ) OR ("Selenocysteine"[MeSH Terms] AND "Archaea"[MeSH Terms] AND "Selenoproteins"[MeSH Terms] AND "Eukaryota"[MeSH Terms] ) OR ("Vigna"[MeSH Terms] AND "Rheology"[MeSH Terms] AND "Selenium"[MeSH Terms] AND "Selenomethionine"[MeSH Terms] AND "Plant Proteins"[MeSH Terms] ) OR ("Amino Acids"[MeSH Terms] AND "Antioxidants"[MeSH Terms] AND "Density Functional Theory"[MeSH Terms] ) OR ("Developmental Disabilities"[MeSH Terms] AND "Thyroxine"[MeSH Terms] AND "Triiodothyronine"[MeSH Terms] ) OR ("Carcinoma, Non-Small-Cell Lung"[MeSH Terms] AND "Lung Neoplasms"[MeSH Terms] AND "Reactive Oxygen Species"[MeSH Terms] AND "Signal Transduction"[MeSH Terms] AND "NF-kappa B"[MeSH Terms] AND "Selenocysteine"[MeSH Terms] AND "Cell Proliferation"[MeSH Terms] AND "Apoptosis"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  2
# Ground truth length is: 2
# Query number 26 is:  Can adult humans be induced to produce fetal hemoglobin?
# Initial article length: 10
# Re-Query is:  ("Cell Differentiation"[MeSH Terms] AND "Erythroid Cells"[MeSH Terms] AND "Gene Expression"[MeSH Terms] ) OR ("Aging"[MeSH Terms] ) OR ("Erythroid Precursor Cells"[MeSH Terms] ) OR ("Genetic Vectors"[MeSH Terms] ) OR ("Hydroxyurea"[MeSH Terms] ) OR ("MicroRNAs"[MeSH Terms] AND "RNA, Long Noncoding"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  18
# Ground truth length is: 18
# Query number 27 is:  Which is the histone residue methylated by MLL1?
# Initial article length: 10
# Re-Query is:  ("Histones"[MeSH Terms] AND "Protein Processing, Post-Translational"[MeSH Terms] ) OR ("Histones"[MeSH Terms] AND "Histone-Lysine N-Methyltransferase"[MeSH Terms] AND "Myeloid-Lymphoid Leukemia Protein"[MeSH Terms] ) OR ("Multiple Endocrine Neoplasia Type 1"[MeSH Terms] ) OR ("Lysine"[MeSH Terms] AND "Neoplasms"[MeSH Terms] ) OR ("Histones"[MeSH Terms] AND "Adipogenesis"[MeSH Terms] ) OR ("Epigenesis, Genetic"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  21
# Ground truth length is: 21
# Query number 28 is:  Which are the two main bacterial phyla in human gut?
# Initial article length: 10
# Re-Query is:  ("Gastrointestinal Microbiome"[MeSH Terms] AND "Colonic Neoplasms"[MeSH Terms] AND "Colorectal Neoplasms"[MeSH Terms] ) OR ("Gastrointestinal Microbiome"[MeSH Terms] ) OR ("Gastrointestinal Microbiome"[MeSH Terms] AND "Breast Neoplasms"[MeSH Terms] ) OR ("Body Weight"[MeSH Terms] AND "Microbiota"[MeSH Terms] ) OR ("Endo-1,4-beta Xylanases"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  2
# Ground truth length is: 2
# Query number 29 is:  Are cardenolides inhibitors of Na+/K+ ATPase?
# Initial article length: 10
# Re-Query is:  ("Cardiac Glycosides"[MeSH Terms] AND "Thyroid Neoplasms"[MeSH Terms] ) OR ("Hypertension"[MeSH Terms] AND "Heart Failure"[MeSH Terms] ) OR ("Intraocular Pressure"[MeSH Terms] AND "Digoxin"[MeSH Terms] AND "Aqueous Humor"[MeSH Terms] AND "Ocular Hypertension"[MeSH Terms] AND "Macaca fascicularis"[MeSH Terms] ) OR ("Colonic Neoplasms"[MeSH Terms] AND "Pinocytosis"[MeSH Terms] AND "Sodium-Potassium-Exchanging ATPase"[MeSH Terms] AND "Wnt Signaling Pathway"[MeSH Terms] ) OR ("Biliary Tract Neoplasms"[MeSH Terms] AND "Antineoplastic Agents"[MeSH Terms] ) OR ("Melitten"[MeSH Terms] AND "Sodium-Potassium-Exchanging ATPase"[MeSH Terms] ) OR ("Biguanides"[MeSH Terms] AND "Acanthamoeba castellanii"[MeSH Terms] AND "Ouabain"[MeSH Terms] ) OR ("Neuroinflammatory Diseases"[MeSH Terms] AND "Ouabain"[MeSH Terms] ) OR ("Cardiac Glycosides"[MeSH Terms] AND "Anti-Infective Agents"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  3
# Ground truth length is: 3
# Query number 30 is:  Sweat Chloride Testing is used  for which disease?
# Initial article length: 8
# Re-Query is:  ("Cystic Fibrosis"[MeSH Terms] AND "Pilocarpine"[MeSH Terms] ) OR ("Cystic Fibrosis"[MeSH Terms] ) OR ("Rifabutin"[MeSH Terms] AND "Cystic Fibrosis"[MeSH Terms] AND "Cystic Fibrosis Transmembrane Conductance Regulator"[MeSH Terms] AND "Aminophenols"[MeSH Terms] AND "Drug Interactions"[MeSH Terms] AND "Benzodioxoles"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  16
# Ground truth length is: 16
# Query number 31 is:  Which gene is mutated in the Karak syndrome?
# Initial article length: 5
# Re-Query is:  ("Genetic Predisposition to Disease"[MeSH Terms] AND "Phenotype"[MeSH Terms] ) OR ("Mutation"[MeSH Terms] AND "Phenotype"[MeSH Terms] ) OR ("Magnetic Resonance Imaging"[MeSH Terms] AND "Mutation"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  6
# Ground truth length is: 6
# Query number 32 is:  Does fibronectin constitute a serum biomarker for Duchenne muscular dystrophy?
# Initial article length: 1
# Re-Query is:
# Initial requery length is: 0
# Length of retrieved list:  1
# Ground truth length is: 1
# Query number 33 is:  Which gene-defect causes the Vel-blood type?
# Initial article length: 0
# Benchmark length is: 2
# Query number 34 is:  In which chromosome are transgenes inserted in the case of the LiPS-A3S line?
# Initial article length: 0
# Benchmark length is: 1
# Query number 35 is:  Which company developed Waylivra?
# Initial article length: 1
# Re-Query is:
# Initial requery length is: 0
# Length of retrieved list:  1
# Ground truth length is: 1
# Query number 36 is:  Which are the characteristics of  Andersen syndrome?
# Initial article length: 10
# Re-Query is:  ("Andersen Syndrome"[MeSH Terms] ) OR ("Electrocardiography"[MeSH Terms] AND "Arrhythmias, Cardiac"[MeSH Terms] AND "Long QT Syndrome"[MeSH Terms] ) OR ("Electrocardiography"[MeSH Terms] ) OR ("Myocardial Infarction"[MeSH Terms] AND "Registries"[MeSH Terms] AND "Heart Disease Risk Factors"[MeSH Terms] ) OR ("Congenital Hyperinsulinism"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  29
# Ground truth length is: 29
# Query number 37 is:  How effective is the dentritic cells treatment on cancer?
# Initial article length: 10
# Re-Query is:  ("Cancer Vaccines"[MeSH Terms] AND "Neoplasms"[MeSH Terms] ) OR ("Sentinel Lymph Node"[MeSH Terms] AND "Metal-Organic Frameworks"[MeSH Terms] AND "Neoplasms"[MeSH Terms] AND "Surgery, Computer-Assisted"[MeSH Terms] ) OR ("Up-Regulation"[MeSH Terms] ) OR ("Leukemia, Myelogenous, Chronic, BCR-ABL Positive"[MeSH Terms] AND "Monocytes"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  12
# Ground truth length is: 12
# Query number 38 is:  What is the typical rash associated with gluten ?
# Initial article length: 1
# Re-Query is:
# Initial requery length is: 0
# Length of retrieved list:  23
# Ground truth length is: 23
# Query number 39 is:  Which disease can be classified with the Awaji Criteria?
# Initial article length: 10
# Re-Query is:  ("Amyotrophic Lateral Sclerosis"[MeSH Terms] ) OR ("Evoked Potentials, Motor"[MeSH Terms] ) OR ("Internationality"[MeSH Terms] AND "Physician's Role"[MeSH Terms] ) OR ("Amyotrophic Lateral Sclerosis"[MeSH Terms] ) OR ("Immune Checkpoint Inhibitors"[MeSH Terms] AND "Pancreatitis"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  26
# Ground truth length is: 26
# Query number 40 is:  Is miR-21 related to carcinogenesis?
# Initial article length: 10
# Re-Query is:  ("MicroRNAs"[MeSH Terms] AND "RNA-Binding Proteins"[MeSH Terms] AND "Lung Neoplasms"[MeSH Terms] AND "Adenocarcinoma of Lung"[MeSH Terms] AND "Gene Expression Regulation, Neoplastic"[MeSH Terms] ) OR ("MicroRNAs"[MeSH Terms] AND "RNA, Long Noncoding"[MeSH Terms] AND "Stomach Neoplasms"[MeSH Terms] ) OR ("Arsenic"[MeSH Terms] AND "Induced Pluripotent Stem Cells"[MeSH Terms] AND "MicroRNAs"[MeSH Terms] ) OR ("Proto-Oncogene Proteins B-raf"[MeSH Terms] AND "MicroRNAs"[MeSH Terms] AND "Thyroid Cancer, Papillary"[MeSH Terms] AND "Thyroid Neoplasms"[MeSH Terms] AND "Lymphatic Metastasis"[MeSH Terms] AND "Mutation"[MeSH Terms] ) OR ("Carcinoma, Non-Small-Cell Lung"[MeSH Terms] AND "MicroRNAs"[MeSH Terms] AND "Lung Neoplasms"[MeSH Terms] ) OR ("Adenoma, Pleomorphic"[MeSH Terms] AND "Salivary Gland Neoplasms"[MeSH Terms] AND "MicroRNAs"[MeSH Terms] AND "Adenocarcinoma"[MeSH Terms] ) OR ("Polychlorinated Biphenyls"[MeSH Terms] AND "Hydrocarbons, Chlorinated"[MeSH Terms] AND "Environmental Pollutants"[MeSH Terms] AND "Pesticides"[MeSH Terms] AND "MicroRNAs"[MeSH Terms] AND "Fluorocarbons"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  98
# Ground truth length is: 98
# Query number 41 is:  What is the mechanism of drug-induced gingival overgrowth?
# Initial article length: 10
# Re-Query is:  ("Gingival Crevicular Fluid"[MeSH Terms] AND "Calcium Channel Blockers"[MeSH Terms] AND "Saliva"[MeSH Terms] AND "Matrix Metalloproteinase 8"[MeSH Terms] AND "Vascular Endothelial Growth Factor A"[MeSH Terms] AND "Hypertension"[MeSH Terms] AND "Biomarkers"[MeSH Terms] ) OR ("Phenytoin"[MeSH Terms] AND "Gingival Overgrowth"[MeSH Terms] ) OR ("Gingival Overgrowth"[MeSH Terms] AND "MicroRNAs"[MeSH Terms] AND "Pharmaceutical Preparations"[MeSH Terms] AND "Zinc Finger E-box Binding Homeobox 2"[MeSH Terms] ) OR ("Gingiva"[MeSH Terms] AND "Gingival Overgrowth"[MeSH Terms] ) OR ("Cell Proliferation"[MeSH Terms] AND "Gingiva"[MeSH Terms] AND "Mesenchymal Stem Cells"[MeSH Terms] AND "MicroRNAs"[MeSH Terms] AND "Osteogenesis"[MeSH Terms] ) OR ("Dendritic Cells, Follicular"[MeSH Terms] AND "Gingival Overgrowth"[MeSH Terms] ) OR ("Cell Proliferation"[MeSH Terms] AND "Gingiva"[MeSH Terms] AND "Mesenchymal Stem Cells"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  7
# Ground truth length is: 7
# Query number 42 is:  What is known about depression in caregivers of brain tumor patients?
# Initial article length: 9
# Re-Query is:  ("Survival Rate"[MeSH Terms] ) OR ("Adaptation, Psychological"[MeSH Terms] AND "Brain Neoplasms"[MeSH Terms] AND "Needs Assessment"[MeSH Terms] AND "Quality of Life"[MeSH Terms] AND "Social Support"[MeSH Terms] ) OR ("Adaptation, Psychological"[MeSH Terms] AND "Attitude to Health"[MeSH Terms] AND "Brain Neoplasms"[MeSH Terms] AND "Cost of Illness"[MeSH Terms] ) OR ("Cost of Illness"[MeSH Terms] AND "Interpersonal Relations"[MeSH Terms] ) OR ("Communication"[MeSH Terms] AND "Health Knowledge, Attitudes, Practice"[MeSH Terms] AND "Quality of Life"[MeSH Terms] ) OR ("Caregivers"[MeSH Terms] AND "Neoplasms"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  19
# Ground truth length is: 19
# Query number 43 is:  Describe CapSim
# Initial article length: 0
# Benchmark length is: 1
# Query number 44 is:  Is low T3 syndrome a prognostic marker in patients with renal insufficiency?
# Initial article length: 1
# Re-Query is:
# Initial requery length is: 0
# Length of retrieved list:  16
# Ground truth length is: 16
# Query number 45 is:  Is Bladder training an effective method to treat  urge incontinence ?
# Initial article length: 10
# Re-Query is:  ("Urinary Incontinence"[MeSH Terms] AND "Urinary Incontinence, Stress"[MeSH Terms] ) OR ("Urinary Bladder, Overactive"[MeSH Terms] AND "Nocturia"[MeSH Terms] AND "Urinary Incontinence"[MeSH Terms] ) OR ("Urinary Incontinence"[MeSH Terms] AND "Urinary Incontinence, Stress"[MeSH Terms] ) OR ("Urinary Incontinence"[MeSH Terms] AND "Urinary Incontinence, Stress"[MeSH Terms] ) OR ("Solifenacin Succinate"[MeSH Terms] AND "Urinary Bladder, Overactive"[MeSH Terms] AND "Biofeedback, Psychology"[MeSH Terms] ) OR ("Nocturia"[MeSH Terms] AND "Urinary Bladder, Neurogenic"[MeSH Terms] AND "Urinary Bladder, Overactive"[MeSH Terms] AND "Urinary Incontinence"[MeSH Terms] ) OR ("Self-Management"[MeSH Terms] AND "Urinary Incontinence"[MeSH Terms] AND "Quality of Life"[MeSH Terms] ) OR ("Urinary Bladder, Overactive"[MeSH Terms] AND "Electric Stimulation Therapy"[MeSH Terms] ) OR ("Urinary Bladder, Overactive"[MeSH Terms] AND "Urinary Incontinence"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  20
# Ground truth length is: 20
# Query number 46 is:  Are circRNAs susceptible to degradation by RNase R?
# Initial article length: 2
# Re-Query is:  ("Carcinoma, Hepatocellular"[MeSH Terms] AND "Gene Expression Regulation, Neoplastic"[MeSH Terms] AND "Liver Neoplasms"[MeSH Terms] AND "MicroRNAs"[MeSH Terms] AND "Neoplasm Proteins"[MeSH Terms] AND "RNA-Binding Proteins"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  17
# Ground truth length is: 17
# Query number 47 is:  What is the cause of the disease Xeroderma Pigmentosum?
# Initial article length: 10
# Re-Query is:  ("Protoporphyria, Erythropoietic"[MeSH Terms] AND "Xeroderma Pigmentosum"[MeSH Terms] AND "Ferrochelatase"[MeSH Terms] ) OR ("B-Lymphocytes"[MeSH Terms] AND "Xeroderma Pigmentosum Group D Protein"[MeSH Terms] AND "Mutation"[MeSH Terms] ) OR ("X-ray Repair Cross Complementing Protein 1"[MeSH Terms] AND "Prostatic Neoplasms"[MeSH Terms] AND "Xeroderma Pigmentosum Group D Protein"[MeSH Terms] AND "Genetic Predisposition to Disease"[MeSH Terms] AND "Polymorphism, Single Nucleotide"[MeSH Terms] ) OR ("Ovarian Neoplasms"[MeSH Terms] AND "DNA Repair"[MeSH Terms] AND "DNA-Binding Proteins"[MeSH Terms] AND "Genetic Predisposition to Disease"[MeSH Terms] AND "Polymorphism, Single Nucleotide"[MeSH Terms] ) OR ("Excision Repair"[MeSH Terms] ) OR ("Mouth Neoplasms"[MeSH Terms] AND "Xeroderma Pigmentosum Group D Protein"[MeSH Terms] AND "Polymorphism, Single Nucleotide"[MeSH Terms] AND "Genetic Predisposition to Disease"[MeSH Terms] ) OR ("Caenorhabditis elegans"[MeSH Terms] AND "DNA Damage"[MeSH Terms] AND "DNA Repair"[MeSH Terms] AND "Transcription Factor TFIIH"[MeSH Terms] AND "DNA-Binding Proteins"[MeSH Terms] AND "Endonucleases"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  5
# Ground truth length is: 5
# Query number 48 is:  Which is the "bonding hormone"?
# Initial article length: 0
# Benchmark length is: 5
# Query number 49 is:  Is the protein KCNQ2 associated with idiopathic epilepsy?
# Initial article length: 10
# Re-Query is:  ("Mutation"[MeSH Terms] ) OR ("Mutation"[MeSH Terms] ) OR ("Mutation"[MeSH Terms] ) OR ("Mutation"[MeSH Terms] ) OR ("Mutation"[MeSH Terms] AND "Receptors, G-Protein-Coupled"[MeSH Terms] ) OR ("Family Health"[MeSH Terms] AND "Genetic Predisposition to Disease"[MeSH Terms] ) OR ("Potassium Channels, Inwardly Rectifying"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  18
# Ground truth length is: 18
# Query number 50 is:  What particles is Hadron therapy using?
# Initial article length: 10
# Re-Query is:  ("Boron Neutron Capture Therapy"[MeSH Terms] ) OR ("Diagnostic Imaging"[MeSH Terms] AND "Proton Therapy"[MeSH Terms] ) OR ("Proton Therapy"[MeSH Terms] AND "Neoplasms"[MeSH Terms] ) OR ("Illusions"[MeSH Terms] AND "Cosmic Radiation"[MeSH Terms] AND "Space Flight"[MeSH Terms] AND "Heavy Ion Radiotherapy"[MeSH Terms] ) OR ("Thyroid Neoplasms"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  3
# Ground truth length is: 3
# Query number 51 is:  In clinical trials, the H3 R antagonist CEP-26401 has a positive effect on cognition, yes or no?
# Initial article length: 0
# Benchmark length is: 3
# Query number 52 is:  Which are the main NMD factors in Saccharomyces cerevisiae?
# Initial article length: 2
# Re-Query is:  ("Gene Expression Regulation, Fungal"[MeSH Terms] ) OR ("Open Reading Frames"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  11
# Ground truth length is: 11
# Query number 53 is:  Of what origin is the MCF-7 cell line?
# Initial article length: 10
# Re-Query is:  ("Breast Neoplasms"[MeSH Terms] AND "Carcinoma"[MeSH Terms] ) OR ("Breast Neoplasms"[MeSH Terms] AND "Cancer-Associated Fibroblasts"[MeSH Terms] ) OR ("Prohibitins"[MeSH Terms] AND "Isothiocyanates"[MeSH Terms] AND "Breast Neoplasms"[MeSH Terms] AND "Apoptosis"[MeSH Terms] AND "Signal Transduction"[MeSH Terms] ) OR ("Immunogenic Cell Death"[MeSH Terms] AND "Melanoma"[MeSH Terms] ) OR ("Plant Extracts"[MeSH Terms] AND "Iris Plant"[MeSH Terms] AND "Phytochemicals"[MeSH Terms] AND "Antineoplastic Agents, Phytogenic"[MeSH Terms] ) OR ("Potentilla"[MeSH Terms] AND "Estrogen Receptor alpha"[MeSH Terms] AND "Phytochemicals"[MeSH Terms] AND "Antineoplastic Agents, Phytogenic"[MeSH Terms] AND "Plant Extracts"[MeSH Terms] AND "Breast Neoplasms"[MeSH Terms] AND "Plant Components, Aerial"[MeSH Terms] ) OR ("Plant Extracts"[MeSH Terms] AND "Uterine Cervical Neoplasms"[MeSH Terms] AND "Breast Neoplasms"[MeSH Terms] AND "Nanoparticles"[MeSH Terms] ) OR ("Microtubules"[MeSH Terms] AND "Golgi Apparatus"[MeSH Terms] AND "Breast Neoplasms"[MeSH Terms] ) OR ("MicroRNAs"[MeSH Terms] AND "Drug Delivery Systems"[MeSH Terms] AND "Nigella sativa"[MeSH Terms] AND "Nanoparticles"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  4
# Ground truth length is: 4
# Query number 54 is:  What is regioneR?
# Initial article length: 10
# Re-Query is:  ("Genomic Instability"[MeSH Terms] AND "Histone-Lysine N-Methyltransferase"[MeSH Terms] AND "Neoplasms"[MeSH Terms] ) OR ("Genomics"[MeSH Terms] AND "Genome"[MeSH Terms] ) OR ("Data Accuracy"[MeSH Terms] AND "Patient Reported Outcome Measures"[MeSH Terms] ) OR ("Gastrointestinal Diseases"[MeSH Terms] AND "Mental Disorders"[MeSH Terms] ) OR ("Pulmonary Embolism"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  1
# Ground truth length is: 1
# Query number 55 is:  List pore forming toxins.
# Initial article length: 10
# Re-Query is:  ("Cnidarian Venoms"[MeSH Terms] AND "Sea Anemones"[MeSH Terms] ) OR ("Algorithms"[MeSH Terms] AND "Evolution, Molecular"[MeSH Terms] AND "Multigene Family"[MeSH Terms] ) OR ("Genes, Bacterial"[MeSH Terms] ) OR ("Gene Expression Profiling"[MeSH Terms] AND "Genomics"[MeSH Terms] AND "Phenotype"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  7
# Ground truth length is: 7
# Query number 56 is:  Between which types of DNA bases are mutational biases introduced due to directional mutation pressure?
# Initial article length: 0
# Benchmark length is: 11
# Query number 57 is:  What is the biological function of the SRY circular RNA (circRNA)?
# Initial article length: 6
# Re-Query is:  ("Nuclear Proteins"[MeSH Terms] AND "Transcription Factors"[MeSH Terms] ) OR ("Gene Expression Regulation"[MeSH Terms] ) OR ("Carcinoma, Hepatocellular"[MeSH Terms] AND "Liver Neoplasms"[MeSH Terms] AND "Radiation Tolerance"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  7
# Ground truth length is: 7
# Query number 58 is:  Which algorithm has been developed for the automatic extraction of co-expressed gene clusters from gene expression data?
# Initial article length: 1
# Re-Query is:
# Initial requery length is: 0
# Length of retrieved list:  1
# Ground truth length is: 1
# Query number 59 is:  Name the phase 3 clinical trials for tofacitinib in colitis.
# Initial article length: 0
# Benchmark length is: 1
# Query number 60 is:  What part of the body is affected by mesotheliomia?
# Initial article length: 0
# Benchmark length is: 3
# Query number 61 is:  Which tool has been developed to identify the glycan shielding of glycosylated proteins?
# Initial article length: 0
# Benchmark length is: 1
# Query number 62 is:  Is the Fluzone intradermal and the Fluzone intradermal quadrivalent vaccine produced by different companies?
# Initial article length: 0
# Benchmark length is: 1
# Query number 63 is:  Is there a link between rare variants in PPARG and type 1 diabetes?
# Initial article length: 0
# Benchmark length is: 1
# Query number 64 is:  What is the proteoform?
# Initial article length: 10
# Re-Query is:  ("COVID-19"[MeSH Terms] AND "Proteomics"[MeSH Terms] AND "SARS-CoV-2"[MeSH Terms] AND "Biomarkers"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  4
# Ground truth length is: 4
# Query number 65 is:  What is known about the Kub5-Hera/RPRD1B interactome?
# Initial article length: 1
# Re-Query is:  ("Genomic Instability"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  1
# Ground truth length is: 1
# Query number 66 is:  Matuzumab has been tested for treatment of which cancers?
# Initial article length: 4
# Re-Query is:  ("Drug Resistance, Neoplasm"[MeSH Terms] ) OR ("ErbB Receptors"[MeSH Terms] AND "Glioma"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  22
# Ground truth length is: 22
# Query number 67 is:  Is creatinine assessment included in the MELD score?
# Initial article length: 10
# Re-Query is:  ("Liver Cirrhosis"[MeSH Terms] AND "Magnetic Resonance Imaging"[MeSH Terms] AND "Biomarkers"[MeSH Terms] AND "Muscle, Skeletal"[MeSH Terms] AND "Severity of Illness Index"[MeSH Terms] ) OR ("Amino Acids, Branched-Chain"[MeSH Terms] AND "Liver Cirrhosis"[MeSH Terms] AND "Quadriceps Muscle"[MeSH Terms] AND "Dietary Supplements"[MeSH Terms] AND "Ultrasonography"[MeSH Terms] AND "Muscle Strength"[MeSH Terms] ) OR ("Acute Kidney Injury"[MeSH Terms] AND "Liver Cirrhosis"[MeSH Terms] AND "Waiting Lists"[MeSH Terms] AND "Arterial Pressure"[MeSH Terms] AND "Liver Transplantation"[MeSH Terms] ) OR ("Liver Transplantation"[MeSH Terms] AND "Mycoses"[MeSH Terms] ) OR ("Esophageal and Gastric Varices"[MeSH Terms] AND "Nomograms"[MeSH Terms] AND "Gastrointestinal Hemorrhage"[MeSH Terms] AND "Recurrence"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  12
# Ground truth length is: 12
# Query number 68 is:  Is arimoclomol a co-inducer of the heat shock response?
# Initial article length: 7
# Re-Query is:  ("Myositis, Inclusion Body"[MeSH Terms] ) OR ("Amyotrophic Lateral Sclerosis"[MeSH Terms] AND "Neuroprotective Agents"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  10
# Ground truth length is: 10
# Query number 69 is:  Is Mediator present at super enhancers?
# Initial article length: 10
# Re-Query is:  ("Transcription Factors"[MeSH Terms] AND "Glioblastoma"[MeSH Terms] ) OR ("Transcription Factors"[MeSH Terms] AND "Neoplasms"[MeSH Terms] ) OR ("Abnormalities, Multiple"[MeSH Terms] AND "Hematologic Diseases"[MeSH Terms] AND "Vestibular Diseases"[MeSH Terms] ) OR ("Enhancer Elements, Genetic"[MeSH Terms] AND "Gene Expression Regulation"[MeSH Terms] ) OR ("Leukemia, Promyelocytic, Acute"[MeSH Terms] AND "Transcription Factors"[MeSH Terms] AND "Cell Cycle Proteins"[MeSH Terms] AND "Oncogene Proteins, Fusion"[MeSH Terms] ) OR ("Histones"[MeSH Terms] AND "Nucleosomes"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  9
# Ground truth length is: 9
# Query number 70 is:  Please list the difference between Pyoderma gangrenosum versus chronic venous ulceration?
# Initial article length: 0
# Benchmark length is: 2
# Query number 71 is:  Which siRNA based drug is in clinical trials for the treatment of pancreatic cancer?
# Initial article length: 10
# Re-Query is:  ("Nanoparticles"[MeSH Terms] AND "Pancreatic Neoplasms"[MeSH Terms] AND "Pharmaceutical Preparations"[MeSH Terms] ) OR ("Molecular Targeted Therapy"[MeSH Terms] ) OR ("RNA Interference"[MeSH Terms] ) OR ("MicroRNAs"[MeSH Terms] AND "Pancreatic Neoplasms"[MeSH Terms] ) OR ("Cancer-Associated Fibroblasts"[MeSH Terms] AND "Colorectal Neoplasms"[MeSH Terms] ) OR ("Carcinoma, Pancreatic Ductal"[MeSH Terms] AND "Pancreatic Neoplasms"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  2
# Ground truth length is: 2
# Query number 72 is:  Does GC content vary markedly within a given isochore?
# Initial article length: 0
# Benchmark length is: 18
# Query number 73 is:  is there an increase in ultrasound comets after intense exercise?
# Initial article length: 3
# Re-Query is:  ("Altitude"[MeSH Terms] AND "Lung Transplantation"[MeSH Terms] AND "Transplant Recipients"[MeSH Terms] AND "Ultrasonography"[MeSH Terms] )
# Initial requery length is: 2
# Length of retrieved list:  13
# Ground truth length is: 13
# Query number 74 is:  What is the role of Thyrotropin Releasing Hormone in the treatment of comatose patients?
# Initial article length: 1
# Re-Query is:
# Initial requery length is: 0
# Length of retrieved list:  9
# Ground truth length is: 9
# Query number 75 is:  What is the causative agent of the "Panama disease" affecting bananas?
# Initial article length: 0
# Benchmark length is: 7
# Query number 76 is:  Which receptor is targeted by Erenumab?
# Initial article length: 10
# Re-Query is:  ("Migraine Disorders"[MeSH Terms] AND "Antibodies, Monoclonal, Humanized"[MeSH Terms] AND "Quality of Life"[MeSH Terms] ) OR ("Antibodies, Monoclonal, Humanized"[MeSH Terms] AND "MicroRNAs"[MeSH Terms] AND "Migraine Disorders"[MeSH Terms] ) OR ("Migraine Disorders"[MeSH Terms] AND "Antibodies, Monoclonal, Humanized"[MeSH Terms] AND "Calcitonin Gene-Related Peptide Receptor Antagonists"[MeSH Terms] ) OR ("Migraine Disorders"[MeSH Terms] AND "Antibodies, Monoclonal, Humanized"[MeSH Terms] AND "Calcitonin Gene-Related Peptide Receptor Antagonists"[MeSH Terms] ) OR ("Migraine Disorders"[MeSH Terms] AND "Calcitonin Gene-Related Peptide"[MeSH Terms] AND "Antibodies, Monoclonal, Humanized"[MeSH Terms] AND "Calcitonin Gene-Related Peptide Receptor Antagonists"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  16
# Ground truth length is: 16
# Query number 77 is:  What is the function of circular RNA?
# Initial article length: 10
# Re-Query is:  ("RNA, Circular"[MeSH Terms] AND "Vaccines, Virus-Like Particle"[MeSH Terms] ) OR ("Aortic Aneurysm, Abdominal"[MeSH Terms] AND "Adenosine"[MeSH Terms] AND "Methyltransferases"[MeSH Terms] AND "Angiotensin II"[MeSH Terms] AND "Muscle, Smooth, Vascular"[MeSH Terms] ) OR ("Urinary Bladder Neoplasms"[MeSH Terms] AND "RNA, Circular"[MeSH Terms] AND "RNA-Binding Proteins"[MeSH Terms] AND "Signal Transduction"[MeSH Terms] AND "PTEN Phosphohydrolase"[MeSH Terms] AND "Phosphatidylinositol 3-Kinases"[MeSH Terms] AND "Cell Movement"[MeSH Terms] ) OR ("Myocardial Infarction"[MeSH Terms] AND "RNA, Circular"[MeSH Terms] ) OR ("Osteosarcoma"[MeSH Terms] AND "MicroRNAs"[MeSH Terms] AND "Cell Proliferation"[MeSH Terms] AND "Glycolysis"[MeSH Terms] AND "RNA, Circular"[MeSH Terms] AND "Transcription Factor 4"[MeSH Terms] ) OR ("MicroRNAs"[MeSH Terms] AND "Osteosarcoma"[MeSH Terms] AND "RNA, Circular"[MeSH Terms] AND "Glial Cell Line-Derived Neurotrophic Factor Receptors"[MeSH Terms] AND "Bone Neoplasms"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  6
# Ground truth length is: 6
# Query number 78 is:  Which is the target of belimumab in Systemic Lupus Erythematosus treatment?
# Initial article length: 10
# Re-Query is:  ("Lupus Erythematosus, Systemic"[MeSH Terms] AND "Drug Development"[MeSH Terms] AND "Antibodies, Monoclonal"[MeSH Terms] AND "Interleukins"[MeSH Terms] ) OR ("Lupus Erythematosus, Systemic"[MeSH Terms] AND "Antibodies, Monoclonal, Humanized"[MeSH Terms] AND "Immunosuppressive Agents"[MeSH Terms] ) OR ("Lupus Nephritis"[MeSH Terms] ) OR ("Antibodies, Monoclonal, Humanized"[MeSH Terms] AND "Biological Products"[MeSH Terms] AND "Lupus Nephritis"[MeSH Terms] ) OR ("Lupus Erythematosus, Systemic"[MeSH Terms] ) OR ("Lupus Nephritis"[MeSH Terms] AND "Immunosuppressive Agents"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  7
# Ground truth length is: 7
# Query number 79 is:  What is the genetic basis of the Delayed Sleep-Phase Syndrome (DSPS)?
# Initial article length: 1
# Re-Query is:
# Initial requery length is: 0
# Length of retrieved list:  8
# Ground truth length is: 8
# Query number 80 is:  Which method has been developed for assignment of enhancers to target genes?
# Initial article length: 10
# Re-Query is:  ("Benchmarking"[MeSH Terms] ) OR ("Breast Neoplasms"[MeSH Terms] ) OR ("Benchmarking"[MeSH Terms] AND "Microbiota"[MeSH Terms] ) OR ("Pharmacogenetics"[MeSH Terms] AND "Computational Biology"[MeSH Terms] ) OR ("Anti-Bacterial Agents"[MeSH Terms] AND "Streptomyces"[MeSH Terms] ) OR ("RNA, Untranslated"[MeSH Terms] AND "Genome"[MeSH Terms] ) OR ("Glioma"[MeSH Terms] AND "Tumor Microenvironment"[MeSH Terms] AND "Biomarkers, Tumor"[MeSH Terms] AND "Neoplastic Stem Cells"[MeSH Terms] AND "Brain Neoplasms"[MeSH Terms] ) OR ("CD28 Antigens"[MeSH Terms] AND "Pancreatic Neoplasms"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  1
# Ground truth length is: 1
# Query number 81 is:  Is physical performance influenced by thyroid hormone metabolism?
# Initial article length: 10
# Re-Query is:  ("Gene Expression Regulation"[MeSH Terms] AND "Motor Activity"[MeSH Terms] AND "Up-Regulation"[MeSH Terms] ) OR ("Physical Conditioning, Animal"[MeSH Terms] ) OR ("Renal Insufficiency, Chronic"[MeSH Terms] AND "Sarcopenia"[MeSH Terms] ) OR ("Hand Strength"[MeSH Terms] ) OR ("Genes"[MeSH Terms] ) OR ("Nutritional Requirements"[MeSH Terms] ) OR ("Thyroxine"[MeSH Terms] AND "Hypothyroidism"[MeSH Terms] ) OR ("Environment"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  8
# Ground truth length is: 8
# Query number 82 is:  Are patients with marfan syndrome at increased risk of arrhythmias?
# Initial article length: 10
# Re-Query is:  ("Mutation"[MeSH Terms] ) OR ("Hospital Mortality"[MeSH Terms] ) OR ("Critical Illness"[MeSH Terms] AND "Disease Management"[MeSH Terms] AND "Postpartum Period"[MeSH Terms] AND "Pregnancy Complications, Cardiovascular"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  3
# Ground truth length is: 3
# Query number 83 is:  What is the function of CR elements in B-cells?
# Initial article length: 10
# Re-Query is:  ("Gene Expression"[MeSH Terms] ) OR ("Cell Movement"[MeSH Terms] ) OR ("Hip Prosthesis"[MeSH Terms] AND "Metal-on-Metal Joint Prostheses"[MeSH Terms] AND "Reoperation"[MeSH Terms] ) OR ("Cryopreservation"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  4
# Ground truth length is: 4
# Query number 84 is:  Which mutations in the cardiac isoform of the ryanodine receptor (RyR2) have been found to be related to CPVT?
# Initial article length: 1
# Re-Query is:  ("Death, Sudden, Cardiac"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  10
# Ground truth length is: 10
# Query number 85 is:  Is Cystatin D a biomarker?
# Initial article length: 0
# Benchmark length is: 1
# Query number 86 is:  Which is the effect of the HP1a protein on chromatin?
# Initial article length: 10
# Re-Query is:  ("Chromobox Protein Homolog 5"[MeSH Terms] AND "Drosophila"[MeSH Terms] AND "Drosophila Proteins"[MeSH Terms] AND "Methyltransferases"[MeSH Terms] ) OR ("Drosophila melanogaster"[MeSH Terms] AND "Drosophila Proteins"[MeSH Terms] ) OR ("Centromere"[MeSH Terms] AND "Heterochromatin"[MeSH Terms] ) OR ("Epigenesis, Genetic"[MeSH Terms] ) OR ("DNA Transposable Elements"[MeSH Terms] AND "RNA-Seq"[MeSH Terms] ) OR ("Pseudomonas Infections"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  11
# Ground truth length is: 11
# Query number 87 is:  The secreted frizzled-related protein 3 (sFPR3) is altered in human cancers.
# Are its level found to increase or to decrease?
# Initial article length: 10
# Re-Query is:  ("Lipid Droplets"[MeSH Terms] AND "Hepatocytes"[MeSH Terms] AND "Fatty Liver"[MeSH Terms] AND "Mice, Knockout"[MeSH Terms] ) OR ("Water"[MeSH Terms] AND "Acer"[MeSH Terms] AND "Starch"[MeSH Terms] )
# Initial requery length is: 7
# Length of retrieved list:  8
# Ground truth length is: 8
# Query number 88 is:  Is Epistaxis associated with dental implant placement?
# ...
# Initial requery length is: 20
# Length of retrieved list:  3
# Ground truth length is: 3
# Query number 207 is:  Is there any role of TBR1 in autism?
# Initial article length: 10
# Re-Query is:  ("Frameshift Mutation"[MeSH Terms] ) OR ("Discrimination, Psychological"[MeSH Terms] AND "Haploinsufficiency"[MeSH Terms] AND "Olfactory Perception"[MeSH Terms] ) OR ("Phenotype"[MeSH Terms] ) OR ("Autism Spectrum Disorder"[MeSH Terms] AND "Kallmann Syndrome"[MeSH Terms] ) OR ("Autism Spectrum Disorder"[MeSH Terms] AND "T-Box Domain Proteins"[MeSH Terms] AND "Disease Models, Animal"[MeSH Terms] AND "Basolateral Nuclear Complex"[MeSH Terms] AND "Social Behavior"[MeSH Terms] AND "Deep Brain Stimulation"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  7
# Ground truth length is: 7
# Query number 208 is:  Which main ribotype of Clostridium difficile is responsible of the recent outbreak?
# Initial article length: 4
# Re-Query is:  ("Clostridioides difficile"[MeSH Terms] AND "Disease Outbreaks"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  9
# Ground truth length is: 9
# Query number 209 is:  Does Evolocumab improve cognitive function?
# Initial article length: 2
# Re-Query is:  ("PCSK9 Inhibitors"[MeSH Terms] AND "Proprotein Convertase 9"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  3
# Ground truth length is: 3
# Query number 210 is:  Which are the key players on radial glial specification to ependymal cells?
# Initial article length: 1
# Re-Query is:
# Initial requery length is: 0
# Length of retrieved list:  2
# Ground truth length is: 2
# Query number 211 is:  Clue cells are characteristics to which causative bacteria of vaginitis?
# Initial article length: 10
# Re-Query is:  ("Gardnerella vaginalis"[MeSH Terms] ) OR ("Emergency Service, Hospital"[MeSH Terms] AND "Models, Theoretical"[MeSH Terms] ) OR ("Mobiluncus"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  7
# Ground truth length is: 7
# Query number 212 is:  Which clotting factor is in the Andexxa?
# Initial article length: 10
# Re-Query is:  ("Anticoagulants"[MeSH Terms] AND "Blood Coagulation Factors"[MeSH Terms] ) OR ("Pipecolic Acids"[MeSH Terms] AND "Sulfonamides"[MeSH Terms] AND "Arginine"[MeSH Terms] AND "Guanidines"[MeSH Terms] AND "Heparin"[MeSH Terms] AND "Benzamidines"[MeSH Terms] ) OR ("Heparin"[MeSH Terms] AND "Anticoagulants"[MeSH Terms] AND "Antithrombins"[MeSH Terms] AND "Recombinant Proteins"[MeSH Terms] AND "Drug Resistance"[MeSH Terms] ) OR ("Heparin"[MeSH Terms] AND "Recombinant Proteins"[MeSH Terms] ) OR ("Aortic Dissection"[MeSH Terms] AND "Factor Xa Inhibitors"[MeSH Terms] AND "Blood Vessel Prosthesis Implantation"[MeSH Terms] ) OR ("Emergency Service, Hospital"[MeSH Terms] AND "Blood Coagulation Factors"[MeSH Terms] AND "Anticoagulants"[MeSH Terms] ) OR ("Anticoagulation Reversal"[MeSH Terms] AND "Cerebral Hemorrhage"[MeSH Terms] AND "Factor Xa"[MeSH Terms] AND "Factor Xa Inhibitors"[MeSH Terms] AND "Recombinant Proteins"[MeSH Terms] ) OR ("Cerebral Hemorrhage"[MeSH Terms] AND "Factor Xa"[MeSH Terms] AND "Factor Xa Inhibitors"[MeSH Terms] AND "Recombinant Proteins"[MeSH Terms] AND "Anticoagulation Reversal"[MeSH Terms] ) OR ("Anticoagulation Reversal"[MeSH Terms] AND "Cerebral Hemorrhage"[MeSH Terms] AND "Factor Xa"[MeSH Terms] AND "Factor Xa Inhibitors"[MeSH Terms] AND "Recombinant Proteins"[MeSH Terms] ) OR ("Anticoagulation Reversal"[MeSH Terms] AND "Cerebral Hemorrhage"[MeSH Terms] AND "Factor Xa"[MeSH Terms] AND "Factor Xa Inhibitors"[MeSH Terms] AND "Recombinant Proteins"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  5
# Ground truth length is: 5
# Query number 213 is:  Could plasmepsins be used as targets for developing anti-malaria drugs?
# Initial article length: 0
# Benchmark length is: 32
# Query number 214 is:  Which ApoE isoform is associated with atherosclerosis and Alzheimer's disease?
# Initial article length: 10
# Re-Query is:  ("Alzheimer Disease"[MeSH Terms] AND "Amyloidosis"[MeSH Terms] ) OR ("Neurodegenerative Diseases"[MeSH Terms] AND "Neoplasms"[MeSH Terms] AND "Alzheimer Disease"[MeSH Terms] ) OR ("Lipid Metabolism"[MeSH Terms] ) OR ("Lipid Metabolism"[MeSH Terms] ) OR ("Deja Vu"[MeSH Terms] AND "Cardiovascular Diseases"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  32
# Ground truth length is: 32
# Query number 215 is:  Are CpG islands located close to housekeeping genes?
# Initial article length: 6
# Re-Query is:  ("Enhancer Elements, Genetic"[MeSH Terms] ) OR ("Chromosomes, Human, Pair 11"[MeSH Terms] ) OR ("Genomic Imprinting"[MeSH Terms] AND "Repressor Proteins"[MeSH Terms] ) OR ("Chromosomes, Human, Pair 8"[MeSH Terms] AND "DNA Helicases"[MeSH Terms] AND "DNA-Binding Proteins"[MeSH Terms] AND "Promoter Regions, Genetic"[MeSH Terms] ) OR ("Chromosome Aberrations"[MeSH Terms] AND "Chromosomes, Human, Pair 3"[MeSH Terms] ) OR ("Biological Evolution"[MeSH Terms] AND "Gene Expression Regulation, Developmental"[MeSH Terms] AND "RNA, Untranslated"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  11
# Ground truth length is: 11
# Query number 216 is:  What is the association between maternal and fetal alloantigens and RANTES production?
# Initial article length: 1
# Re-Query is:
# Initial requery length is: 0
# Length of retrieved list:  3
# Ground truth length is: 3
# Query number 217 is:  Does SARM1 deletion cause neurodegeneration?
# Initial article length: 10
# Re-Query is:  ("Amyotrophic Lateral Sclerosis"[MeSH Terms] ) OR ("Charcot-Marie-Tooth Disease"[MeSH Terms] AND "Demyelinating Diseases"[MeSH Terms] ) OR ("Amyotrophic Lateral Sclerosis"[MeSH Terms] AND "Armadillo Domain Proteins"[MeSH Terms] AND "Cytoskeletal Proteins"[MeSH Terms] AND "Neurodegenerative Diseases"[MeSH Terms] ) OR ("Alzheimer Disease"[MeSH Terms] ) OR ("Spastic Paraplegia, Hereditary"[MeSH Terms] ) OR ("Charcot-Marie-Tooth Disease"[MeSH Terms] ) OR ("Wallerian Degeneration"[MeSH Terms] AND "Brain Injuries, Traumatic"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  1
# Ground truth length is: 1
# Query number 218 is:  List available biomedical question answering systems.
# Initial article length: 10
# Re-Query is:  ("Natural Language Processing"[MeSH Terms] ) OR ("Checklist"[MeSH Terms] ) OR ("Abstracting and Indexing"[MeSH Terms] AND "Algorithms"[MeSH Terms] AND "Information Storage and Retrieval"[MeSH Terms] AND "Natural Language Processing"[MeSH Terms] AND "Oligonucleotide Array Sequence Analysis"[MeSH Terms] AND "Semantics"[MeSH Terms] AND "Software"[MeSH Terms] ) OR ("Periodicals as Topic"[MeSH Terms] AND "Toxicogenetics"[MeSH Terms] ) OR ("Deep Learning"[MeSH Terms] AND "COVID-19"[MeSH Terms] ) OR ("Biomedical Technology"[MeSH Terms] AND "Delphi Technique"[MeSH Terms] ) OR ("Mobile Applications"[MeSH Terms] ) OR ("Biomedical Research"[MeSH Terms] AND "Clinical Trials as Topic"[MeSH Terms] AND "Medical Records Systems, Computerized"[MeSH Terms] AND "Organizational Policy"[MeSH Terms] ) OR ("Paraplegia"[MeSH Terms] AND "Spinal Cord Injuries"[MeSH Terms] AND "Health Personnel"[MeSH Terms] AND "Caregivers"[MeSH Terms] AND "Biomedical Research"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  3
# Ground truth length is: 3
# Query number 219 is:  Does sphingosine-1 phosphoate suppress epiregulin?
# Initial article length: 0
# Benchmark length is: 1
# Query number 220 is:  Are OATP1B1 and OATP1B3 associated with bilirubin transport?
# Initial article length: 10
# Re-Query is:  ("Genetic Therapy"[MeSH Terms] ) OR ("Organic Anion Transporters"[MeSH Terms] AND "Hyperbilirubinemia, Hereditary"[MeSH Terms] ) OR ("Chemical and Drug Induced Liver Injury"[MeSH Terms] AND "Drug-Related Side Effects and Adverse Reactions"[MeSH Terms] AND "Emodin"[MeSH Terms] AND "Fallopia multiflora"[MeSH Terms] AND "Polygonum"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  13
# Ground truth length is: 13
# Query number 221 is:  What is the function of Neu5Gc (N-Glycolylneuraminic acid)?
# Initial article length: 10
# Re-Query is:  ("Neuraminic Acids"[MeSH Terms] AND "N-Acetylneuraminic Acid"[MeSH Terms] ) OR ("Influenza A Virus, H3N2 Subtype"[MeSH Terms] AND "Sialic Acids"[MeSH Terms] AND "Virus Internalization"[MeSH Terms] AND "Host Microbial Interactions"[MeSH Terms] ) OR ("Influenza A virus"[MeSH Terms] AND "Influenza, Human"[MeSH Terms] AND "Orthomyxoviridae"[MeSH Terms] ) OR ("Infant Formula"[MeSH Terms] AND "Sialic Acids"[MeSH Terms] ) OR ("Network Pharmacology"[MeSH Terms] AND "Colorectal Neoplasms"[MeSH Terms] ) OR ("Escherichia coli"[MeSH Terms] AND "Escherichia coli Infections"[MeSH Terms] ) OR ("NF-kappa B"[MeSH Terms] AND "Chlorpromazine"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  6
# Ground truth length is: 6
# Query number 222 is:  Which cancer is associated with increased levels of Serum alpha fetoprotein (AFP) ?
# Initial article length: 10
# Re-Query is:  ("Wilms Tumor"[MeSH Terms] AND "alpha-Fetoproteins"[MeSH Terms] AND "Biomarkers, Tumor"[MeSH Terms] AND "Kidney Neoplasms"[MeSH Terms] ) OR ("Neoplasms, Germ Cell and Embryonal"[MeSH Terms] AND "Ovarian Neoplasms"[MeSH Terms] ) OR ("Carcinoma, Hepatocellular"[MeSH Terms] AND "Alkanesulfonic Acids"[MeSH Terms] AND "Environmental Pollutants"[MeSH Terms] AND "Liver Neoplasms"[MeSH Terms] AND "Fluorocarbons"[MeSH Terms] ) OR ("Biomarkers"[MeSH Terms] AND "Hepatitis B, Chronic"[MeSH Terms] AND "Klotho Proteins"[MeSH Terms] AND "Carcinoma, Hepatocellular"[MeSH Terms] ) OR ("Carcinoma, Hepatocellular"[MeSH Terms] AND "Liver Neoplasms"[MeSH Terms] AND "Hepatitis B"[MeSH Terms] AND "Hepatitis B, Chronic"[MeSH Terms] ) OR ("Carcinoma, Hepatocellular"[MeSH Terms] AND "Liver Neoplasms"[MeSH Terms] AND "Mitochondrial Diseases"[MeSH Terms] AND "Signal Transduction"[MeSH Terms] ) OR ("Carcinoma, Hepatocellular"[MeSH Terms] AND "Liver Neoplasms"[MeSH Terms] ) OR ("Carcinoma, Hepatocellular"[MeSH Terms] AND "Liver Neoplasms"[MeSH Terms] AND "Sarcopenia"[MeSH Terms] AND "Chemoembolization, Therapeutic"[MeSH Terms] ) OR ("Carcinoma, Hepatocellular"[MeSH Terms] AND "Liver Neoplasms"[MeSH Terms] AND "Chemoembolization, Therapeutic"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  5
# Ground truth length is: 5
# Query number 223 is:  Please list the tests used to diagnose Allergic Rhinitis.
# Initial article length: 0
# Benchmark length is: 24
# Query number 224 is:  Describe CrossICC
# Initial article length: 0
# Benchmark length is: 1
# Query number 225 is:  CURB65 score is used for stratification of which disease?
# Initial article length: 10
# Re-Query is:  ("COVID-19"[MeSH Terms] ) OR ("Community-Acquired Infections"[MeSH Terms] AND "Frailty"[MeSH Terms] AND "Pneumonia"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  9
# Ground truth length is: 9
# Query number 226 is:  Which conditions is caused by mutations in HFE?
# Initial article length: 9
# Re-Query is:  ("Hemochromatosis"[MeSH Terms] AND "Mutation, Missense"[MeSH Terms] AND "Phenotype"[MeSH Terms] AND "Severity of Illness Index"[MeSH Terms] ) OR ("Mutation"[MeSH Terms] ) OR ("Polycythemia"[MeSH Terms] AND "Polycythemia Vera"[MeSH Terms] ) OR ("Mutation"[MeSH Terms] AND "Quality of Life"[MeSH Terms] ) OR ("Hemochromatosis"[MeSH Terms] AND "Alcoholism"[MeSH Terms] AND "Ferroptosis"[MeSH Terms] AND "Gastrointestinal Microbiome"[MeSH Terms] AND "Iron Overload"[MeSH Terms] AND "Liver Neoplasms"[MeSH Terms] ) OR ("Autoimmunity"[MeSH Terms] AND "Family"[MeSH Terms] AND "Homozygote"[MeSH Terms] AND "Mutation"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  31
# Ground truth length is: 31
# Query number 227 is:  Describe GREEKC
# Initial article length: 1
# Re-Query is:  ("Gene Expression Regulation"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  1
# Ground truth length is: 1
# Query number 228 is:  Which deep learning-based algorithms are used for enhancer prediction?
# Initial article length: 10
# Re-Query is:  ("COVID-19"[MeSH Terms] AND "Deep Learning"[MeSH Terms] AND "Social Media"[MeSH Terms] AND "Natural Language Processing"[MeSH Terms] ) OR ("Protein Conformation"[MeSH Terms] AND "Molecular Dynamics Simulation"[MeSH Terms] ) OR ("Peptides, Cyclic"[MeSH Terms] AND "Cell Membrane Permeability"[MeSH Terms] ) OR ("Liver Neoplasms"[MeSH Terms] AND "Radiotherapy Planning, Computer-Assisted"[MeSH Terms] AND "Radiotherapy Dosage"[MeSH Terms] AND "Deep Learning"[MeSH Terms] ) OR ("Ceramics"[MeSH Terms] AND "Deep Learning"[MeSH Terms] AND "Microscopy, Electron, Scanning"[MeSH Terms] ) OR ("Metabolic Syndrome"[MeSH Terms] AND "Machine Learning"[MeSH Terms] ) OR ("Deep Learning"[MeSH Terms] AND "Mandibular Condyle"[MeSH Terms] AND "Cone-Beam Computed Tomography"[MeSH Terms] AND "Imaging, Three-Dimensional"[MeSH Terms] ) OR ("Deep Learning"[MeSH Terms] AND "High-Intensity Focused Ultrasound Ablation"[MeSH Terms] ) OR ("Carcinoma, Non-Small-Cell Lung"[MeSH Terms] AND "Deep Learning"[MeSH Terms] AND "Lung Neoplasms"[MeSH Terms] AND "Neoadjuvant Therapy"[MeSH Terms] AND "Tomography, X-Ray Computed"[MeSH Terms] ) OR ("Deep Learning"[MeSH Terms] AND "Electrocardiography"[MeSH Terms] AND "Heart Defects, Congenital"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  5
# Ground truth length is: 5
# Query number 229 is:  What body process does the Dentate Gyrus Mossy Cell control?
# Initial article length: 3
# Re-Query is:  ("Mossy Fibers, Hippocampal"[MeSH Terms] AND "Cerebellar Cortex"[MeSH Terms] )
# Initial requery length is: 8
# Length of retrieved list:  6
# Ground truth length is: 6
# Query number 230 is:  List off label uses for Rituximab.
# Initial article length: 4
# Re-Query is:  ("Multiple Sclerosis, Relapsing-Remitting"[MeSH Terms] AND "Multiple Sclerosis"[MeSH Terms] AND "Biosimilar Pharmaceuticals"[MeSH Terms] ) OR ("Arthritis, Rheumatoid"[MeSH Terms] AND "Rheumatic Diseases"[MeSH Terms] AND "Rheumatology"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  6
# Ground truth length is: 6
# Query number 231 is:  Can leuprorelin acetate be used as androgen deprivation therapy?
# Initial article length: 10
# Re-Query is:  ("Prostatic Neoplasms"[MeSH Terms] AND "Androgen Antagonists"[MeSH Terms] AND "Quality of Life"[MeSH Terms] AND "Gonadotropin-Releasing Hormone"[MeSH Terms] AND "5-alpha Reductase Inhibitors"[MeSH Terms] ) OR ("Prostatic Neoplasms"[MeSH Terms] AND "Androgen Antagonists"[MeSH Terms] ) OR ("Prostatic Neoplasms"[MeSH Terms] AND "Leuprolide"[MeSH Terms] AND "Radiosurgery"[MeSH Terms] AND "Neoplasm Recurrence, Local"[MeSH Terms] ) OR ("Prostatic Neoplasms"[MeSH Terms] ) OR ("Androgen Antagonists"[MeSH Terms] AND "Prostatic Neoplasms, Castration-Resistant"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  1
# Ground truth length is: 1
# Query number 232 is:  List two most common symptoms of Aagenaes syndrome.
# Initial article length: 0
# Benchmark length is: 13
# Query number 233 is:  Do only changes in coding regions of MEF2C cause developmental disorders?
# Initial article length: 0
# Benchmark length is: 1
# Query number 234 is:  What is the mechanism of action of raxibacumab?
# Initial article length: 10
# Re-Query is:  ("Anthrax"[MeSH Terms] AND "Bacillus anthracis"[MeSH Terms] ) OR ("Anthrax"[MeSH Terms] AND "Bacillus anthracis"[MeSH Terms] ) OR ("Bacillus anthracis"[MeSH Terms] ) OR ("Anthrax"[MeSH Terms] AND "Bacillus anthracis"[MeSH Terms] AND "Communicable Diseases"[MeSH Terms] AND "Respiratory Tract Infections"[MeSH Terms] ) OR ("Bacillus anthracis"[MeSH Terms] AND "Bacterial Toxins"[MeSH Terms] AND "Clostridioides difficile"[MeSH Terms] )
# Initial requery length is: 20
# Length of retrieved list:  11
# Ground truth length is: 11
# List successfully written to evaluation/evaluation_metrics.csv

# %%
len(ground_truth_list)
# Out:
# 237

# %%
first_half = ground_truth_list[1:][0:187]

# %%
length_check(retrieved_ids_list, ground_truth_list[1:])
# Out:
# Different length!
# Inconsistency at index: 0 where retrieved ids have length: 5 and ground truth has length 15
# Inconsistency at index: 1 where retrieved ids have length: 15 and ground truth has length 4
# Inconsistency at index: 2 where retrieved ids have length: 4 and ground truth has length 18
# Inconsistency at index: 3 where retrieved ids have length: 18 and ground truth has length 4
# Inconsistency at index: 4 where retrieved ids have length: 4 and ground truth has length 15
# Inconsistency at index: 5 where retrieved ids have length: 15 and ground truth has length 2
# Inconsistency at index: 6 where retrieved ids have length: 2 and ground truth has length 20
# Inconsistency at index: 7 where retrieved ids have length: 20 and ground truth has length 6
# Inconsistency at index: 8 where retrieved ids have length: 6 and ground truth has length 4
# Inconsistency at index: 9 where retrieved ids have length: 4 and ground truth has length 13
# Inconsistency at index: 10 where retrieved ids have length: 13 and ground truth has length 1
# Inconsistency at index: 11 where retrieved ids have length: 1 and ground truth has length 9
# Inconsistency at index: 12 where retrieved ids have length: 9 and ground truth has length 17
# Inconsistency at index: 14 where retrieved ids have length: 17 and ground truth has length 1
# Inconsistency at index: 16 where retrieved ids have length: 0 and ground truth has length 16
# Inconsistency at index: 17 where retrieved ids have length: 16 and ground truth has length 19
# Inconsistency at index: 18 where retrieved ids have length: 19 and ground truth has length 5
# Inconsistency at index: 19 where retrieved ids have length: 5 and ground truth has length 17
# Inconsistency at index: 20 where retrieved ids have length: 17 and ground truth has length 9
# Inconsistency at index: 21 where retrieved ids have length: 9 and ground truth has length 8
# Inconsistency at index: 22 where retrieved ids have length: 8 and ground truth has length 1
# Inconsistency at index: 23 where retrieved ids have length: 1 and ground truth has length 7
# Inconsistency at index: 24 where retrieved ids have length: 0 and ground truth has length 2
# Inconsistency at index: 25 where retrieved ids have length: 2 and ground truth has length 18
# Inconsistency at index: 26 where retrieved ids have length: 18 and ground truth has length 21
# Inconsistency at index: 27 where retrieved ids have length: 21 and ground truth has length 2
# Inconsistency at index: 28 where retrieved ids have length: 2 and ground truth has length 3
# Inconsistency at index: 29 where retrieved ids have length: 3 and ground truth has length 16
# Inconsistency at index: 30 where retrieved ids have length: 16 and ground truth has length 6
# Inconsistency at index: 31 where retrieved ids have length: 6 and ground truth has length 1
# Inconsistency at index: 32 where retrieved ids have length: 1 and ground truth has length 2
# Inconsistency at index: 33 where retrieved ids have length: 0 and ground truth has length 1
# Inconsistency at index: 34 where retrieved ids have length: 0 and ground truth has length 1
# Inconsistency at index: 35 where retrieved ids have length: 1 and ground truth has length 29
# Inconsistency at index: 36 where retrieved ids have length: 29 and ground truth has length 12
# Inconsistency at index: 37 where retrieved ids have length: 12 and ground truth has length 23
# Inconsistency at index: 38 where retrieved ids have length: 23 and ground truth has length 26
# Inconsistency at index: 39 where retrieved ids have length: 26 and ground truth has length 98
# Inconsistency at index: 40 where retrieved ids have length: 98 and ground truth has length 7
# Inconsistency at index: 41 where retrieved ids have length: 7 and ground truth has length 19
# Inconsistency at index: 42 where retrieved ids have length: 19 and ground truth has length 1
# Inconsistency at index: 43 where retrieved ids have length: 0 and ground truth has length 16
# Inconsistency at index: 44 where retrieved ids have length: 16 and ground truth has length 20
# Inconsistency at index: 45 where retrieved ids have length: 20 and ground truth has length 17
# Inconsistency at index: 46 where retrieved ids have length: 17 and ground truth has length 5
# Inconsistency at index: 48 where retrieved ids have length: 0 and ground truth has length 18
# Inconsistency at index: 49 where retrieved ids have length: 18 and ground truth has length 3
# Inconsistency at index: 51 where retrieved ids have length: 0 and ground truth has length 11
# Inconsistency at index: 52 where retrieved ids have length: 11 and ground truth has length 4
# Inconsistency at index: 53 where retrieved ids have length: 4 and ground truth has length 1
# Inconsistency at index: 54 where retrieved ids have length: 1 and ground truth has length 7
# Inconsistency at index: 55 where retrieved ids have length: 7 and ground truth has length 11
# Inconsistency at index: 56 where retrieved ids have length: 0 and ground truth has length 7
# Inconsistency at index: 57 where retrieved ids have length: 7 and ground truth has length 1
# Inconsistency at index: 59 where retrieved ids have length: 0 and ground truth has length 3
# Inconsistency at index: 60 where retrieved ids have length: 0 and ground truth has length 1
# Inconsistency at index: 61 where retrieved ids have length: 0 and ground truth has length 1
# Inconsistency at index: 62 where retrieved ids have length: 0 and ground truth has length 1
# Inconsistency at index: 63 where retrieved ids have length: 0 and ground truth has length 4
# Inconsistency at index: 64 where retrieved ids have length: 4 and ground truth has length 1
# Inconsistency at index: 65 where retrieved ids have length: 1 and ground truth has length 22
# Inconsistency at index: 66 where retrieved ids have length: 22 and ground truth has length 12
# Inconsistency at index: 67 where retrieved ids have length: 12 and ground truth has length 10
# Inconsistency at index: 68 where retrieved ids have length: 10 and ground truth has length 9
# Inconsistency at index: 69 where retrieved ids have length: 9 and ground truth has length 2
# Inconsistency at index: 70 where retrieved ids have length: 0 and ground truth has length 2
# Inconsistency at index: 71 where retrieved ids have length: 2 and ground truth has length 18
# Inconsistency at index: 72 where retrieved ids have length: 0 and ground truth has length 13
# Inconsistency at index: 73 where retrieved ids have length: 13 and ground truth has length 9
# Inconsistency at index: 74 where retrieved ids have length: 9 and ground truth has length 7
# Inconsistency at index: 75 where retrieved ids have length: 0 and ground truth has length 16
# Inconsistency at index: 76 where retrieved ids have length: 16 and ground truth has length 6
# Inconsistency at index: 77 where retrieved ids have length: 6 and ground truth has length 7
# Inconsistency at index: 78 where retrieved ids have length: 7 and ground truth has length 8
# Inconsistency at index: 79 where retrieved ids have length: 8 and ground truth has length 1
# Inconsistency at index: 80 where retrieved ids have length: 1 and ground truth has length 8
# Inconsistency at index: 81 where retrieved ids have length: 8 and ground truth has length 3
# Inconsistency at index: 82 where retrieved ids have length: 3 and ground truth has length 4
# Inconsistency at index: 83 where retrieved ids have length: 4 and ground truth has length 10
# Inconsistency at index: 84 where retrieved ids have length: 10 and ground truth has length 1
# Inconsistency at index: 85 where retrieved ids have length: 0 and ground truth has length 11
# Inconsistency at index: 86 where retrieved ids have length: 11 and ground truth has length 8
# Inconsistency at index: 92 where retrieved ids have length: 0 and ground truth has length 9
# Inconsistency at index: 102 where retrieved ids have length: 0 and ground truth has length 7
# Inconsistency at index: 105 where retrieved ids have length: 0 and ground truth has length 1
# Inconsistency at index: 106 where retrieved ids have length: 0 and ground truth has length 8
# Inconsistency at index: 109 where retrieved ids have length: 0 and ground truth has length 2
# Inconsistency at index: 122 where retrieved ids have length: 0 and ground truth has length 8
# Inconsistency at index: 136 where retrieved ids have length: 0 and ground truth has length 1
# Inconsistency at index: 141 where retrieved ids have length: 0 and ground truth has length 3
# Inconsistency at index: 144 where retrieved ids have length: 0 and ground truth has length 16
# Inconsistency at index: 145 where retrieved ids have length: 0 and ground truth has length 14
# Inconsistency at index: 150 where retrieved ids have length: 0 and ground truth has length 5
# Inconsistency at index: 152 where retrieved ids have length: 0 and ground truth has length 3
# Inconsistency at index: 155 where retrieved ids have length: 0 and ground truth has length 1
# Inconsistency at index: 159 where retrieved ids have length: 0 and ground truth has length 1
# Inconsistency at index: 164 where retrieved ids have length: 0 and ground truth has length 2
# Inconsistency at index: 170 where retrieved ids have length: 0 and ground truth has length 6
# Inconsistency at index: 179 where retrieved ids have length: 0 and ground truth has length 1
# Inconsistency at index: 184 where retrieved ids have length: 0 and ground truth has length 12
# Inconsistency at index: 188 where retrieved ids have length: 13 and ground truth has length 4
# Inconsistency at index: 189 where retrieved ids have length: 20 and ground truth has length 13
# Inconsistency at index: 190 where retrieved ids have length: 13 and ground truth has length 20
# Inconsistency at index: 191 where retrieved ids have length: 4 and ground truth has length 13
# Inconsistency at index: 192 where retrieved ids have length: 2 and ground truth has length 4
# Inconsistency at index: 193 where retrieved ids have length: 5 and ground truth has length 2
# Inconsistency at index: 194 where retrieved ids have length: 0 and ground truth has length 5
# Inconsistency at index: 195 where retrieved ids have length: 15 and ground truth has length 3
# Inconsistency at index: 196 where retrieved ids have length: 3 and ground truth has length 15
# Inconsistency at index: 197 where retrieved ids have length: 0 and ground truth has length 3
# Inconsistency at index: 198 where retrieved ids have length: 11 and ground truth has length 16
# Inconsistency at index: 199 where retrieved ids have length: 3 and ground truth has length 11
# Inconsistency at index: 200 where retrieved ids have length: 0 and ground truth has length 3
# Inconsistency at index: 201 where retrieved ids have length: 13 and ground truth has length 10
# Inconsistency at index: 202 where retrieved ids have length: 0 and ground truth has length 13
# Inconsistency at index: 203 where retrieved ids have length: 13 and ground truth has length 1
# Inconsistency at index: 204 where retrieved ids have length: 16 and ground truth has length 13
# Inconsistency at index: 205 where retrieved ids have length: 1 and ground truth has length 16
# Inconsistency at index: 206 where retrieved ids have length: 3 and ground truth has length 1
# Inconsistency at index: 207 where retrieved ids have length: 7 and ground truth has length 3
# Inconsistency at index: 208 where retrieved ids have length: 9 and ground truth has length 7
# Inconsistency at index: 209 where retrieved ids have length: 3 and ground truth has length 9
# Inconsistency at index: 210 where retrieved ids have length: 2 and ground truth has length 3
# Inconsistency at index: 211 where retrieved ids have length: 7 and ground truth has length 2
# Inconsistency at index: 212 where retrieved ids have length: 5 and ground truth has length 7
# Inconsistency at index: 213 where retrieved ids have length: 0 and ground truth has length 5
# Inconsistency at index: 215 where retrieved ids have length: 11 and ground truth has length 32
# Inconsistency at index: 216 where retrieved ids have length: 3 and ground truth has length 11
# Inconsistency at index: 217 where retrieved ids have length: 1 and ground truth has length 3
# Inconsistency at index: 218 where retrieved ids have length: 3 and ground truth has length 1
# Inconsistency at index: 219 where retrieved ids have length: 0 and ground truth has length 3
# Inconsistency at index: 220 where retrieved ids have length: 13 and ground truth has length 1
# Inconsistency at index: 221 where retrieved ids have length: 6 and ground truth has length 13
# Inconsistency at index: 222 where retrieved ids have length: 5 and ground truth has length 6
# Inconsistency at index: 223 where retrieved ids have length: 0 and ground truth has length 5
# Inconsistency at index: 224 where retrieved ids have length: 0 and ground truth has length 24
# Inconsistency at index: 225 where retrieved ids have length: 9 and ground truth has length 1
# Inconsistency at index: 226 where retrieved ids have length: 31 and ground truth has length 9
# Inconsistency at index: 227 where retrieved ids have length: 1 and ground truth has length 31
# Inconsistency at index: 228 where retrieved ids have length: 5 and ground truth has length 1
# Inconsistency at index: 229 where retrieved ids have length: 6 and ground truth has length 5
# Inconsistency at index: 231 where retrieved ids have length: 1 and ground truth has length 6
# Inconsistency at index: 232 where retrieved ids have length: 0 and ground truth has length 1
# Inconsistency at index: 233 where retrieved ids have length: 0 and ground truth has length 13
# Inconsistency at index: 234 where retrieved ids have length: 11 and ground truth has length 1
# 145
